# %% [markdown]
# # Share 5 - BAG
# ## Campylobacteriosis
# * Übersicht: https://www.idd.bag.admin.ch/de/diseases/campylobacteriosis/overview
# * Daten: https://www.idd.bag.admin.ch/de/diseases/campylobacteriosis/data
#
# Werden monatlich geupdatet
#
# Obligatorische Meldung

# %%
# Importieren der Libraries

# Daten-Analyse
import pandas as pd

# Daten-Visualisierung
import altair as alt

# %% [markdown]
# ### Daten hereinladen

# %%
# Daten laden --> read_csv / read_excel
# Falls mehrere sheets --> sheet_name="sheet"


data = pd.read_csv("data/campylobacteriosis/data.csv")

data
# Out:
#         valueCategory  temporal temporal_type georegion georegion_type  \
# 0               cases  2013-M01         month      CHFL           CHFL
# 1               cases  2013-M02         month      CHFL           CHFL
# 2               cases  2013-M03         month      CHFL           CHFL
# 3               cases  2013-M04         month      CHFL           CHFL
# 4               cases  2013-M05         month      CHFL           CHFL
# ..                ...       ...           ...       ...            ...
# 750  cases_10y_cumsum      2024          year      CHFL           CHFL
# 751  cases_10y_cumsum      2024          year      CHFL           CHFL
# 752  cases_10y_cumsum      2025          year      CHFL           CHFL
# 753  cases_10y_cumsum      2025          year      CHFL           CHFL
# 754  cases_10y_cumsum      2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex    value        pop  incValue  \
# 0        all  agegroup_food      all    810.0  8176573.0      9.91
# 1        all  agegroup_food      all    339.0  8176573.0      4.15
# 2        all  agegroup_food      all    299.0  8176573.0      3.66
# 3        all  agegroup_food      all    405.0  8176573.0      4.95
# 4        all  agegroup_food      all    488.0  8176573.0      5.97
# ..       ...            ...      ...      ...        ...       ...
# 750      all  agegroup_food     male  39656.0        NaN       NaN
# 751      all  agegroup_food  unknown    457.0        NaN       NaN
# 752      all  agegroup_food   female  33293.0        NaN       NaN
# 753      all  agegroup_food     male  40954.0        NaN       NaN
# 754      all  agegroup_food  unknown    400.0        NaN       NaN
#
#      valueYearCumSum  valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0              810.0          NaN       NaN   NaN         NaN            NaN
# 1             1149.0          NaN       NaN   NaN         NaN            NaN
# 2             1448.0          NaN       NaN   NaN         NaN            NaN
# 3             1853.0          NaN  stagnant   NaN         NaN            NaN
# 4             2341.0          NaN    rising   NaN         NaN            NaN
# ..               ...          ...       ...   ...         ...            ...
# 750              NaN          NaN       NaN  54.5         NaN            NaN
# 751              NaN          NaN       NaN   0.6         NaN            NaN
# 752              NaN          NaN       NaN  44.6         NaN            NaN
# 753              NaN          NaN       NaN  54.9         NaN            NaN
# 754              NaN          NaN       NaN   0.5         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 750                 NaN          NaN          True
# 751                 NaN          NaN          True
# 752                 NaN          NaN          True
# 753                 NaN          NaN          True
# 754                 NaN          NaN          True
#
# [755 rows x 20 columns]

# %% [markdown]
# ### Variablen

# %%
data.columns
# Out:
# Index(['valueCategory', 'temporal', 'temporal_type', 'georegion',
#        'georegion_type', 'agegroup', 'agegroup_type', 'sex', 'value', 'pop',
#        'incValue', 'valueYearCumSum', 'valueMean3y', 'trend', 'prct',
#        'deltaValue', 'deltaIncValue', 'incValuePrctChange', 'valueMean5y',
#        'dataComplete'],
#       dtype='object')

# %% [markdown]
# * valueCategory: Was gemessen wird --> Hier: Anzahl gemeldete Fälle
# * temporal: Welcher Zeitabschnitt --> Jahr und Monat
# * temporal_type: Typ der Zeit --> Monat
# * georegion: Kanton oder Land --> hier Anfang Land später Kanton
# * georegion_type: Typ der Georegion --> Land/Kantonal
# * agegroup: Alterskategorie
# * agegroup_type: Zuordnung zur Oberthema --> bei allen gleich
# * sex: Geschlecht
# * value: Wert basierend auf vorhergehende Kategorien
# * pop: Bevölkerung zum Zeitpunkt der Erhebung
# * incValue: neuaufgetrettene Fälle innerhalb der Gruppe und Zeit
# * valueYearCumSum: Gesamter Wert über das Jahr
# * valueMean3y: Durchschnittswert der letzten drei Jahre
# * trend: ist der Trend abnehmend(falling), gleich(stagnant) oder steigend(rising)
# * prct: prozentualer Anteil der Fälle in den Kategorien und Zeiteinheit
# * deltaValue: Unterschied des value zum vorherigen Wert
# * deltaIncValue: Unterschied des incValue zum vorherigen Wert
# * incValuePrctChange: Prozentualer Unterschied zum vorherigen Wert
# * valueMean5y: Durchschnittlicher Wert der letzten 5 Jahre
# * dataComplete: ist dieser Datenpunkt komplett

# %%
data.dtypes
# Out:
# valueCategory          object
# temporal               object
# temporal_type          object
# georegion              object
# georegion_type         object
# agegroup               object
# agegroup_type          object
# sex                    object
# value                 float64
# pop                   float64
# incValue              float64
# valueYearCumSum       float64
# valueMean3y           float64
# trend                  object
# prct                  float64
# deltaValue            float64
# deltaIncValue         float64
# incValuePrctChange    float64
# valueMean5y           float64
# dataComplete             bool
# dtype: object

# %% [markdown]
# ### Datensatz für Cases
#
# --> Die Durchschnittswerte sind als Einzelne Datenpunkte erhoben

# %%
data_def = data[data["valueCategory"] == "cases"]

data_def
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 714         cases      2025          year        UR         canton      all
# 715         cases      2025          year        VD         canton      all
# 716         cases      2025          year        VS         canton      all
# 717         cases      2025          year        ZG         canton      all
# 718         cases      2025          year        ZH         canton      all
#
#      agegroup_type  sex   value        pop  incValue  valueYearCumSum  \
# 0    agegroup_food  all   810.0  8176573.0      9.91            810.0
# 1    agegroup_food  all   339.0  8176573.0      4.15           1149.0
# 2    agegroup_food  all   299.0  8176573.0      3.66           1448.0
# 3    agegroup_food  all   405.0  8176573.0      4.95           1853.0
# 4    agegroup_food  all   488.0  8176573.0      5.97           2341.0
# ..             ...  ...     ...        ...       ...              ...
# 714  agegroup_food  all    20.0    38275.0     52.25              NaN
# 715  agegroup_food  all  1040.0   855106.0    121.62              NaN
# 716  agegroup_food  all   507.0   371288.0    136.55              NaN
# 717  agegroup_food  all   116.0   133739.0     86.74              NaN
# 718  agegroup_food  all  1379.0  1620020.0     85.12              NaN
#
#      valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0            NaN       NaN   NaN         NaN            NaN
# 1            NaN       NaN   NaN         NaN            NaN
# 2            NaN       NaN   NaN         NaN            NaN
# 3            NaN  stagnant   NaN         NaN            NaN
# 4            NaN    rising   NaN         NaN            NaN
# ..           ...       ...   ...         ...            ...
# 714         23.3       NaN   0.2         NaN            NaN
# 715        952.7       NaN  12.0         NaN            NaN
# 716        462.0       NaN   5.8         NaN            NaN
# 717        107.3       NaN   1.3         NaN            NaN
# 718       1187.3       NaN  15.9         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 714                 NaN          NaN          True
# 715                 NaN          NaN          True
# 716                 NaN          NaN          True
# 717                 NaN          NaN          True
# 718                 NaN          NaN          True
#
# [551 rows x 20 columns]

# %% [markdown]
# ### Datensatz für Agegroup

# %%
data_med = data[data["valueCategory"] == "cases_10y_mean"]

data_med
# Out:
#       valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 719  cases_10y_mean     2022          year      CHFL           CHFL   0 - 16
# 720  cases_10y_mean     2022          year      CHFL           CHFL  17 - 24
# 721  cases_10y_mean     2022          year      CHFL           CHFL  25 - 44
# 722  cases_10y_mean     2022          year      CHFL           CHFL  45 - 64
# 723  cases_10y_mean     2022          year      CHFL           CHFL      65+
# 724  cases_10y_mean     2022          year      CHFL           CHFL  unknown
# 725  cases_10y_mean     2023          year      CHFL           CHFL   0 - 16
# 726  cases_10y_mean     2023          year      CHFL           CHFL  17 - 24
# 727  cases_10y_mean     2023          year      CHFL           CHFL  25 - 44
# 728  cases_10y_mean     2023          year      CHFL           CHFL  45 - 64
# 729  cases_10y_mean     2023          year      CHFL           CHFL      65+
# 730  cases_10y_mean     2023          year      CHFL           CHFL  unknown
# 731  cases_10y_mean     2024          year      CHFL           CHFL   0 - 16
# 732  cases_10y_mean     2024          year      CHFL           CHFL  17 - 24
# 733  cases_10y_mean     2024          year      CHFL           CHFL  25 - 44
# 734  cases_10y_mean     2024          year      CHFL           CHFL  45 - 64
# 735  cases_10y_mean     2024          year      CHFL           CHFL      65+
# 736  cases_10y_mean     2024          year      CHFL           CHFL  unknown
# 737  cases_10y_mean     2025          year      CHFL           CHFL   0 - 16
# 738  cases_10y_mean     2025          year      CHFL           CHFL  17 - 24
# 739  cases_10y_mean     2025          year      CHFL           CHFL  25 - 44
# 740  cases_10y_mean     2025          year      CHFL           CHFL  45 - 64
# 741  cases_10y_mean     2025          year      CHFL           CHFL      65+
# 742  cases_10y_mean     2025          year      CHFL           CHFL  unknown
#
#      agegroup_type  sex  value  pop  incValue  valueYearCumSum  valueMean3y  \
# 719  agegroup_food  all    NaN  NaN     66.68              NaN          NaN
# 720  agegroup_food  all    NaN  NaN    129.40              NaN          NaN
# 721  agegroup_food  all    NaN  NaN     79.53              NaN          NaN
# 722  agegroup_food  all    NaN  NaN     75.56              NaN          NaN
# 723  agegroup_food  all    NaN  NaN    102.75              NaN          NaN
# 724  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
# 725  agegroup_food  all    NaN  NaN     64.56              NaN          NaN
# 726  agegroup_food  all    NaN  NaN    125.16              NaN          NaN
# 727  agegroup_food  all    NaN  NaN     77.21              NaN          NaN
# 728  agegroup_food  all    NaN  NaN     74.70              NaN          NaN
# 729  agegroup_food  all    NaN  NaN    102.67              NaN          NaN
# 730  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
# 731  agegroup_food  all    NaN  NaN     63.84              NaN          NaN
# 732  agegroup_food  all    NaN  NaN    124.13              NaN          NaN
# 733  agegroup_food  all    NaN  NaN     76.86              NaN          NaN
# 734  agegroup_food  all    NaN  NaN     75.16              NaN          NaN
# 735  agegroup_food  all    NaN  NaN    104.28              NaN          NaN
# 736  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
# 737  agegroup_food  all    NaN  NaN     63.93              NaN          NaN
# 738  agegroup_food  all    NaN  NaN    124.94              NaN          NaN
# 739  agegroup_food  all    NaN  NaN     77.30              NaN          NaN
# 740  agegroup_food  all    NaN  NaN     76.64              NaN          NaN
# 741  agegroup_food  all    NaN  NaN    108.48              NaN          NaN
# 742  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
#
#     trend  prct  deltaValue  deltaIncValue  incValuePrctChange  valueMean5y  \
# 719   NaN   NaN         NaN            NaN                 NaN          NaN
# 720   NaN   NaN         NaN            NaN                 NaN          NaN
# 721   NaN   NaN         NaN            NaN                 NaN          NaN
# 722   NaN   NaN         NaN            NaN                 NaN          NaN
# 723   NaN   NaN         NaN            NaN                 NaN          NaN
# 724   NaN   NaN         NaN            NaN                 NaN          NaN
# 725   NaN   NaN         NaN            NaN                 NaN          NaN
# 726   NaN   NaN         NaN            NaN                 NaN          NaN
# 727   NaN   NaN         NaN            NaN                 NaN          NaN
# 728   NaN   NaN         NaN            NaN                 NaN          NaN
# 729   NaN   NaN         NaN            NaN                 NaN          NaN
# 730   NaN   NaN         NaN            NaN                 NaN          NaN
# 731   NaN   NaN         NaN            NaN                 NaN          NaN
# 732   NaN   NaN         NaN            NaN                 NaN          NaN
# 733   NaN   NaN         NaN            NaN                 NaN          NaN
# 734   NaN   NaN         NaN            NaN                 NaN          NaN
# 735   NaN   NaN         NaN            NaN                 NaN          NaN
# 736   NaN   NaN         NaN            NaN                 NaN          NaN
# 737   NaN   NaN         NaN            NaN                 NaN          NaN
# 738   NaN   NaN         NaN            NaN                 NaN          NaN
# 739   NaN   NaN         NaN            NaN                 NaN          NaN
# 740   NaN   NaN         NaN            NaN                 NaN          NaN
# 741   NaN   NaN         NaN            NaN                 NaN          NaN
# 742   NaN   NaN         NaN            NaN                 NaN          NaN
#
#      dataComplete
# 719          True
# 720          True
# 721          True
# 722          True
# 723          True
# 724          True
# 725          True
# 726          True
# 727          True
# 728          True
# 729          True
# 730          True
# 731          True
# 732          True
# 733          True
# 734          True
# 735          True
# 736          True
# 737          True
# 738          True
# 739          True
# 740          True
# 741          True
# 742          True

# %%
# Exportieren des Datensatzes für Fälle pro Altersklasse
# data_med.to_csv("./export/data_campylobacteriosis_fälle_altersklasse.csv", index=False)

# %% [markdown]
# ### Datensatz für Geschlecht

# %%
data_sex = data[data["valueCategory"] == "cases_10y_cumsum"]

data_sex
# Out:
#         valueCategory temporal temporal_type georegion georegion_type  \
# 743  cases_10y_cumsum     2022          year      CHFL           CHFL
# 744  cases_10y_cumsum     2022          year      CHFL           CHFL
# 745  cases_10y_cumsum     2022          year      CHFL           CHFL
# 746  cases_10y_cumsum     2023          year      CHFL           CHFL
# 747  cases_10y_cumsum     2023          year      CHFL           CHFL
# 748  cases_10y_cumsum     2023          year      CHFL           CHFL
# 749  cases_10y_cumsum     2024          year      CHFL           CHFL
# 750  cases_10y_cumsum     2024          year      CHFL           CHFL
# 751  cases_10y_cumsum     2024          year      CHFL           CHFL
# 752  cases_10y_cumsum     2025          year      CHFL           CHFL
# 753  cases_10y_cumsum     2025          year      CHFL           CHFL
# 754  cases_10y_cumsum     2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex    value  pop  incValue  valueYearCumSum  \
# 743      all  agegroup_food   female  32962.0  NaN       NaN              NaN
# 744      all  agegroup_food     male  39264.0  NaN       NaN              NaN
# 745      all  agegroup_food  unknown    528.0  NaN       NaN              NaN
# 746      all  agegroup_food   female  32486.0  NaN       NaN              NaN
# 747      all  agegroup_food     male  39009.0  NaN       NaN              NaN
# 748      all  agegroup_food  unknown    492.0  NaN       NaN              NaN
# 749      all  agegroup_food   female  32688.0  NaN       NaN              NaN
# 750      all  agegroup_food     male  39656.0  NaN       NaN              NaN
# 751      all  agegroup_food  unknown    457.0  NaN       NaN              NaN
# 752      all  agegroup_food   female  33293.0  NaN       NaN              NaN
# 753      all  agegroup_food     male  40954.0  NaN       NaN              NaN
# 754      all  agegroup_food  unknown    400.0  NaN       NaN              NaN
#
#      valueMean3y trend  prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 743          NaN   NaN  45.3         NaN            NaN                 NaN
# 744          NaN   NaN  54.0         NaN            NaN                 NaN
# 745          NaN   NaN   0.7         NaN            NaN                 NaN
# 746          NaN   NaN  45.1         NaN            NaN                 NaN
# 747          NaN   NaN  54.2         NaN            NaN                 NaN
# 748          NaN   NaN   0.7         NaN            NaN                 NaN
# 749          NaN   NaN  44.9         NaN            NaN                 NaN
# 750          NaN   NaN  54.5         NaN            NaN                 NaN
# 751          NaN   NaN   0.6         NaN            NaN                 NaN
# 752          NaN   NaN  44.6         NaN            NaN                 NaN
# 753          NaN   NaN  54.9         NaN            NaN                 NaN
# 754          NaN   NaN   0.5         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 743          NaN          True
# 744          NaN          True
# 745          NaN          True
# 746          NaN          True
# 747          NaN          True
# 748          NaN          True
# 749          NaN          True
# 750          NaN          True
# 751          NaN          True
# 752          NaN          True
# 753          NaN          True
# 754          NaN          True

# %%
# Exportieren des Datensatzes für Fälle Geschlechterverteilung
# data_sex.to_csv("./export/data_campylobacteriosis_fälle_geschlecht.csv", index=False)

# %% [markdown]
# ### Visuelle Analyse

# %%
# Ohne Kantone --> ~
data_cantons = data_def[~data_def["georegion"].isin(["CH", "CHFL"])]

#Gruppieren nach georegion und Werte summieren
counts = (
    data_cantons.groupby("georegion")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_georegion = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("sum_value", title="Total Cases")
).properties(
    title="Campylobacteriosis Georegion 2013-2025"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * ZH am höchsten --> grösster Kanton
# * kleine Kantone --> weniger Fälle

# %%
# nur 2025
data_cantons_2025 = data_cantons[data_cantons["temporal"] == "2025"]

#Gruppieren nach georegion und Werte summieren
counts = (
    data_cantons_2025.groupby("georegion")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_georegion_2025 = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("sum_value", title="Total Cases")
).properties(
    title="Campylobacteriosis Georegion 2025"
)

# Textlabels
text = bar_georegion_2025.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_georegion_2025 = bar_georegion_2025 + text
bar_georegion_2025
# Out:
# alt.LayerChart(...)

# %%
data_1 = data_def.copy()

data_year = data_1[data_1["temporal_type"] == "year"]

data_year
# Out:
#     valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 332         cases     2013          year        AG         canton      all
# 333         cases     2013          year        AI         canton      all
# 334         cases     2013          year        AR         canton      all
# 335         cases     2013          year        BE         canton      all
# 336         cases     2013          year        BL         canton      all
# ..            ...      ...           ...       ...            ...      ...
# 714         cases     2025          year        UR         canton      all
# 715         cases     2025          year        VD         canton      all
# 716         cases     2025          year        VS         canton      all
# 717         cases     2025          year        ZG         canton      all
# 718         cases     2025          year        ZH         canton      all
#
#      agegroup_type  sex   value        pop  incValue  valueYearCumSum  \
# 332  agegroup_food  all   546.0   636362.0     85.80              NaN
# 333  agegroup_food  all    25.0    15778.0    158.45              NaN
# 334  agegroup_food  all    52.0    53691.0     96.85              NaN
# 335  agegroup_food  all   958.0  1001281.0     95.68              NaN
# 336  agegroup_food  all   417.0   278656.0    149.65              NaN
# ..             ...  ...     ...        ...       ...              ...
# 714  agegroup_food  all    20.0    38275.0     52.25              NaN
# 715  agegroup_food  all  1040.0   855106.0    121.62              NaN
# 716  agegroup_food  all   507.0   371288.0    136.55              NaN
# 717  agegroup_food  all   116.0   133739.0     86.74              NaN
# 718  agegroup_food  all  1379.0  1620020.0     85.12              NaN
#
#      valueMean3y trend  prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 332          NaN   NaN   7.3         NaN            NaN                 NaN
# 333          NaN   NaN   0.3         NaN            NaN                 NaN
# 334          NaN   NaN   0.7         NaN            NaN                 NaN
# 335          NaN   NaN  12.8         NaN            NaN                 NaN
# 336          NaN   NaN   5.6         NaN            NaN                 NaN
# ..           ...   ...   ...         ...            ...                 ...
# 714         23.3   NaN   0.2         NaN            NaN                 NaN
# 715        952.7   NaN  12.0         NaN            NaN                 NaN
# 716        462.0   NaN   5.8         NaN            NaN                 NaN
# 717        107.3   NaN   1.3         NaN            NaN                 NaN
# 718       1187.3   NaN  15.9         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 332          NaN          True
# 333          NaN          True
# 334          NaN          True
# 335          NaN          True
# 336          NaN          True
# ..           ...           ...
# 714          NaN          True
# 715          NaN          True
# 716          NaN          True
# 717          NaN          True
# 718          NaN          True
#
# [387 rows x 20 columns]

# %%
# Exportieren des Datensatzes für Fälle pro Kanton
# data_year.to_csv("./export/data_campylobacteriosis_fälle_georegion.csv", index=False)

# %%
# Ohne Kantone
data_year_CH = data_year[data_year["georegion"].isin(["CH"])]

bar_year = alt.Chart(data_year_CH).mark_bar().encode(
    x=alt.X("temporal", title="Temporal"),
    y=alt.Y("value", title="Cases")
).properties(
    title="Campylobacteriosis Year"
)

# Textlabels
text = bar_year.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_year = bar_year + text
bar_year
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * Steigende Fallzahlen in den letzten Jahren

# %%
data_2 = data_def.copy()

data_month = data_2[data_2["temporal_type"] == "month"]

data_month
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 159         cases  2026-M04         month      CHFL           CHFL      all
# 160         cases  2026-M05         month      CHFL           CHFL      all
# 161         cases  2026-M06         month      CHFL           CHFL      all
# 162         cases  2026-M07         month      CHFL           CHFL      all
# 163         cases  2026-M08         month      CHFL           CHFL      all
#
#      agegroup_type  sex   value        pop  incValue  valueYearCumSum  \
# 0    agegroup_food  all   810.0  8176573.0      9.91            810.0
# 1    agegroup_food  all   339.0  8176573.0      4.15           1149.0
# 2    agegroup_food  all   299.0  8176573.0      3.66           1448.0
# 3    agegroup_food  all   405.0  8176573.0      4.95           1853.0
# 4    agegroup_food  all   488.0  8176573.0      5.97           2341.0
# ..             ...  ...     ...        ...       ...              ...
# 159  agegroup_food  all   563.0  9091674.0      6.19           2252.0
# 160  agegroup_food  all   851.0  9091674.0      9.36           3103.0
# 161  agegroup_food  all  1096.0  9091674.0     12.05           4199.0
# 162  agegroup_food  all  1280.0  9091674.0     14.08           5479.0
# 163  agegroup_food  all  1392.0  9091674.0     15.31           6871.0
#
#      valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0            NaN       NaN   NaN         NaN            NaN
# 1            NaN       NaN   NaN         NaN            NaN
# 2            NaN       NaN   NaN         NaN            NaN
# 3            NaN  stagnant   NaN         NaN            NaN
# 4            NaN    rising   NaN         NaN            NaN
# ..           ...       ...   ...         ...            ...
# 159          NaN  stagnant   NaN         NaN            NaN
# 160          NaN    rising   NaN         NaN            NaN
# 161          NaN    rising   NaN         NaN            NaN
# 162          NaN    rising   NaN         NaN            NaN
# 163          NaN    rising   NaN         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 159                 NaN          NaN          True
# 160                 NaN          NaN          True
# 161                 NaN          NaN          True
# 162                 NaN          NaN          True
# 163                 NaN          NaN          True
#
# [164 rows x 20 columns]

# %%
# Exportieren des Datensatzes für Fälle pro Monat
# data_month.to_csv("./export/data_campylobacteriosis_fälle_monat.csv", index=False)

# %%
#Gruppieren nach Jahren und Werte summieren


bar_month = alt.Chart(data_month).mark_bar().encode(
    x=alt.X("temporal:N", title="Temporal"),
    y=alt.Y("value:Q", title="Cases"),
    color=alt.Color("trend:N")
).properties(
    title="Campylobacteriosis Month"
)

# Textlabels
text = bar_month.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_month = bar_month + text
bar_month
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * im Sommer am Höchsten¨
# * im Winter tiefer
# * steigende Zahlen in den letzten Jahren

# %%
bar_age = alt.Chart(data_med).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases"),
    color=alt.Color("temporal")
).properties(
    title="Campylobacteriosis Altersgruppen 2022 - 2025"
)

bar_age
# Out:
# alt.Chart(...)

# %%
data_age_2025 = data_med[data_med["temporal"] == "2025"]

bar_age_2 = alt.Chart(data_age_2025).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases")
).properties(
    title="Campylobacteriosis Altersgruppen 2025"
)

# Textlabels
text = bar_age_2.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="incValue:Q"
)

bar_age_2 = bar_age_2 + text

bar_age_2
# Out:
# alt.LayerChart(...)

# %%
bar_sex = alt.Chart(data_sex).mark_bar().encode(
    x=alt.X("sex", title="Sex"),
    y=alt.Y("value", title="Cases"),
    color=alt.Color("temporal")
).properties(
    title="Campylobacteriosis Geschlechterverteilung 2022 - 2025"
)

bar_sex
# Out:
# alt.Chart(...)

# %%
data_sex_2025 = data_sex[data_sex["temporal"] == "2025"]

bar_sex_2 = alt.Chart(data_sex_2025).mark_bar().encode(
    x=alt.X("sex", title="Geschlecht"),
    y=alt.Y("value", title="Cases")
).properties(
    title="Campylobacteriosis Geschlechterverteilung 2025"
)

# Textlabels
text = bar_sex_2.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_sex_2 = bar_sex_2 + text
bar_sex_2
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Durchschnittsberechnungen & -visualisierungen

# %%
# Ohne Kantone --> ~
data_cantons = data_def[~data_def["georegion"].isin(["CH", "CHFL"])]

#Gruppieren nach georegion und Werte summieren
counts_mean = (
    data_cantons.groupby("georegion")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

#Bar Chart
bar_georegion = alt.Chart(counts_mean).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("mean_value", title="Mean Cases")
).properties(
    title="Campylobacteriosis Georegion 2013-2025 Mean"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)

# %%
# Jahr und Monat trennen
data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)

data_month
# Out:
# /var/folders/wr/rgnzqf8x4w501ytwkhks5qfw0000gn/T/ipykernel_27492/2880901401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)
# /var/folders/wr/rgnzqf8x4w501ytwkhks5qfw0000gn/T/ipykernel_27492/2880901401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 159         cases  2026-M04         month      CHFL           CHFL      all
# 160         cases  2026-M05         month      CHFL           CHFL      all
# 161         cases  2026-M06         month      CHFL           CHFL      all
# 162         cases  2026-M07         month      CHFL           CHFL      all
# 163         cases  2026-M08         month      CHFL           CHFL      all
#
#      agegroup_type  sex   value        pop  ...  valueMean3y     trend  prct  \
# 0    agegroup_food  all   810.0  8176573.0  ...          NaN       NaN   NaN
# 1    agegroup_food  all   339.0  8176573.0  ...          NaN       NaN   NaN
# 2    agegroup_food  all   299.0  8176573.0  ...          NaN       NaN   NaN
# 3    agegroup_food  all   405.0  8176573.0  ...          NaN  stagnant   NaN
# 4    agegroup_food  all   488.0  8176573.0  ...          NaN    rising   NaN
# ..             ...  ...     ...        ...  ...          ...       ...   ...
# 159  agegroup_food  all   563.0  9091674.0  ...          NaN  stagnant   NaN
# 160  agegroup_food  all   851.0  9091674.0  ...          NaN    rising   NaN
# 161  agegroup_food  all  1096.0  9091674.0  ...          NaN    rising   NaN
# 162  agegroup_food  all  1280.0  9091674.0  ...          NaN    rising   NaN
# 163  agegroup_food  all  1392.0  9091674.0  ...          NaN    rising   NaN
#
#     deltaValue  deltaIncValue  incValuePrctChange  valueMean5y  dataComplete  \
# 0          NaN            NaN                 NaN          NaN          True
# 1          NaN            NaN                 NaN          NaN          True
# 2          NaN            NaN                 NaN          NaN          True
# 3          NaN            NaN                 NaN          NaN          True
# 4          NaN            NaN                 NaN          NaN          True
# ..         ...            ...                 ...          ...           ...
# 159        NaN            NaN                 NaN          NaN          True
# 160        NaN            NaN                 NaN          NaN          True
# 161        NaN            NaN                 NaN          NaN          True
# 162        NaN            NaN                 NaN          NaN          True
# 163        NaN            NaN                 NaN          NaN          True
#
#      year  month
# 0    2013    M01
# 1    2013    M02
# 2    2013    M03
# 3    2013    M04
# 4    2013    M05
# ..    ...    ...
# 159  2026    M04
# 160  2026    M05
# 161  2026    M06
# 162  2026    M07
# 163  2026    M08
#
# [164 rows x 22 columns]

# %%
counts_mean = (
    data_month.groupby("month")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

bar_month = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("month:N", title="Month"),
    y=alt.Y("mean_value:Q", title="Cases")
).properties(
    title="Campylobacteriosis Month 2013-2026 Mean"
)

# Textlabels
text = bar_month.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_month = bar_month + text
bar_month
# Out:
# alt.LayerChart(...)

# %%
counts_mean = (
    data_med.groupby("agegroup")
        .agg(mean_value=("incValue", "mean")).round(0)
        .reset_index()
)

bar_age = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("mean_value", title="Cases")
).properties(
    title="Campylobacteriosis Altersgruppen 2022 - 2025 Mean IncValue"
)

# Textlabels
text = bar_age.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_age = bar_age + text
bar_age
# Out:
# alt.LayerChart(...)

# %%
counts_mean = (
    data_sex.groupby("sex")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

bar_sex = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("sex", title="Sex"),
    y=alt.Y("mean_value", title="Cases")
).properties(
    title="Campylobacteriosis Geschlechterverteilung 2022 - 2025 Mean"
)

# Textlabels
text = bar_sex.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_sex = bar_sex + text
bar_sex

bar_sex
# Out:
# alt.LayerChart(...)
