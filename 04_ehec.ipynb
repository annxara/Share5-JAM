# %% [markdown]
# # Share 5 - BAG
# ## EHEC - Enterohämorrhagische Escherichia coli-Infektion
# * Übersicht: https://www.idd.bag.admin.ch/de/diseases/ehec/overview
# * Daten: https://www.idd.bag.admin.ch/de/diseases/ehec/data
#
# Werden monatlich geupdatet
#
# Oblig. Meldung

# %%
# Importieren der Libraries

# Daten-Analyse
import pandas as pd

# Daten-Visualisierung
import altair as alt

# %% [markdown]
# ### Daten hereinladen

# %%
# Daten laden --> read_csv / read_excel
# Falls mehrere sheets --> sheet_name="sheet"


data = pd.read_csv("data/ehec/data.csv")

data
# Out:
#         valueCategory  temporal temporal_type georegion georegion_type  \
# 0               cases  2013-M01         month      CHFL           CHFL
# 1               cases  2013-M02         month      CHFL           CHFL
# 2               cases  2013-M03         month      CHFL           CHFL
# 3               cases  2013-M04         month      CHFL           CHFL
# 4               cases  2013-M05         month      CHFL           CHFL
# ..                ...       ...           ...       ...            ...
# 766  cases_10y_cumsum      2024          year      CHFL           CHFL
# 767  cases_10y_cumsum      2024          year      CHFL           CHFL
# 768  cases_10y_cumsum      2025          year      CHFL           CHFL
# 769  cases_10y_cumsum      2025          year      CHFL           CHFL
# 770  cases_10y_cumsum      2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex type   value  ...  incValue  \
# 0        all  agegroup_food      all  all     2.0  ...      0.02
# 1        all  agegroup_food      all  all     0.0  ...      0.00
# 2        all  agegroup_food      all  all     6.0  ...      0.07
# 3        all  agegroup_food      all  all     8.0  ...      0.10
# 4        all  agegroup_food      all  all     6.0  ...      0.07
# ..       ...            ...      ...  ...     ...  ...       ...
# 766      all  agegroup_food     male  all  3928.0  ...       NaN
# 767      all  agegroup_food  unknown  all    10.0  ...       NaN
# 768      all  agegroup_food   female  all  5569.0  ...       NaN
# 769      all  agegroup_food     male  all  4427.0  ...       NaN
# 770      all  agegroup_food  unknown  all    11.0  ...       NaN
#
#      valueYearCumSum  valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0                2.0          NaN       NaN   NaN         NaN            NaN
# 1                2.0          NaN       NaN   NaN         NaN            NaN
# 2                8.0          NaN       NaN   NaN         NaN            NaN
# 3               16.0          NaN    rising   NaN         NaN            NaN
# 4               22.0          NaN  stagnant   NaN         NaN            NaN
# ..               ...          ...       ...   ...         ...            ...
# 766              NaN          NaN       NaN  44.3         NaN            NaN
# 767              NaN          NaN       NaN   0.1         NaN            NaN
# 768              NaN          NaN       NaN  55.7         NaN            NaN
# 769              NaN          NaN       NaN  44.2         NaN            NaN
# 770              NaN          NaN       NaN   0.1         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 766                 NaN          NaN          True
# 767                 NaN          NaN          True
# 768                 NaN          NaN          True
# 769                 NaN          NaN          True
# 770                 NaN          NaN          True
#
# [771 rows x 21 columns]

# %% [markdown]
# ### Variablen

# %%
data.columns
# Out:
# Index(['valueCategory', 'temporal', 'temporal_type', 'georegion',
#        'georegion_type', 'agegroup', 'agegroup_type', 'sex', 'type', 'value',
#        'pop', 'incValue', 'valueYearCumSum', 'valueMean3y', 'trend', 'prct',
#        'deltaValue', 'deltaIncValue', 'incValuePrctChange', 'valueMean5y',
#        'dataComplete'],
#       dtype='object')

# %% [markdown]
# * valueCategory: Was gemessen wird --> Hier: Anzahl gemeldete Fälle
# * temporal: Welcher Zeitabschnitt --> Jahr und Monat
# * temporal_type: Typ der Zeit --> Monat
# * georegion: Kanton oder Land --> hier Anfang Land später Kanton
# * georegion_type: Typ der Georegion --> Land/Kantonal
# * agegroup: Alterskategorie
# * agegroup_type: Zuordnung zur Oberthema --> bei allen gleich
# * sex: Geschlecht
# * value: Wert basierend auf vorhergehende Kategorien
# * pop: Bevölkerung zum Zeitpunkt der Erhebung
# * incValue: neuaufgetrettene Fälle innerhalb der Gruppe und Zeit
# * valueYearCumSum: Gesamter Wert über das Jahr
# * valueMean3y: Durchschnittswert der letzten drei Jahre
# * trend: ist der Trend abnehmend(falling), gleich(stagnant) oder steigend(rising)
# * prct: prozentualer Anteil der Fälle in den Kategorien und Zeiteinheit
# * deltaValue: Unterschied des value zum vorherigen Wert
# * deltaIncValue: Unterschied des incValue zum vorherigen Wert
# * incValuePrctChange: Prozentualer Unterschied zum vorherigen Wert
# * valueMean5y: Durchschnittlicher Wert der letzten 5 Jahre
# * dataComplete: ist dieser Datenpunkt komplett

# %%
data.dtypes
# Out:
# valueCategory          object
# temporal               object
# temporal_type          object
# georegion              object
# georegion_type         object
# agegroup               object
# agegroup_type          object
# sex                    object
# type                   object
# value                 float64
# pop                   float64
# incValue              float64
# valueYearCumSum       float64
# valueMean3y           float64
# trend                  object
# prct                  float64
# deltaValue            float64
# deltaIncValue         float64
# incValuePrctChange    float64
# valueMean5y           float64
# dataComplete             bool
# dtype: object

# %% [markdown]
# ### Datensatz für Cases
#
# --> Die Durchschnittswerte sind als Einzelne Datenpunkte erhoben

# %%
data_def = data[data["valueCategory"] == "cases"]

data_def
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 730         cases      2023          year      CHFL           CHFL      all
# 731         cases      2024          year      CHFL           CHFL      all
# 732         cases      2024          year      CHFL           CHFL      all
# 733         cases      2025          year      CHFL           CHFL      all
# 734         cases      2025          year      CHFL           CHFL      all
#
#      agegroup_type  sex     type   value  ...  incValue  valueYearCumSum  \
# 0    agegroup_food  all      all     2.0  ...      0.02              2.0
# 1    agegroup_food  all      all     0.0  ...      0.00              2.0
# 2    agegroup_food  all      all     6.0  ...      0.07              8.0
# 3    agegroup_food  all      all     8.0  ...      0.10             16.0
# 4    agegroup_food  all      all     6.0  ...      0.07             22.0
# ..             ...  ...      ...     ...  ...       ...              ...
# 730  agegroup_food  all  non-hus  1217.0  ...     13.52              NaN
# 731  agegroup_food  all      hus    24.0  ...      0.26              NaN
# 732  agegroup_food  all  non-hus  1368.0  ...     15.05              NaN
# 733  agegroup_food  all      hus    23.0  ...      0.25              NaN
# 734  agegroup_food  all  non-hus  1423.0  ...     15.65              NaN
#
#      valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0            NaN       NaN   NaN         NaN            NaN
# 1            NaN       NaN   NaN         NaN            NaN
# 2            NaN       NaN   NaN         NaN            NaN
# 3            NaN    rising   NaN         NaN            NaN
# 4            NaN  stagnant   NaN         NaN            NaN
# ..           ...       ...   ...         ...            ...
# 730       1105.3       NaN  98.2         NaN            NaN
# 731         23.3       NaN   1.7         NaN            NaN
# 732       1255.3       NaN  98.3         NaN            NaN
# 733         23.0       NaN   1.6         NaN            NaN
# 734       1336.0       NaN  98.4         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 730                 NaN          NaN          True
# 731                 NaN          NaN          True
# 732                 NaN          NaN          True
# 733                 NaN          NaN          True
# 734                 NaN          NaN          True
#
# [567 rows x 21 columns]

# %% [markdown]
# ### Datensatz für Durchschnittswerte & Agegroup

# %%
data_med = data[data["valueCategory"] == "cases_10y_mean"]

data_med
# Out:
#       valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 735  cases_10y_mean     2022          year      CHFL           CHFL   0 - 16
# 736  cases_10y_mean     2022          year      CHFL           CHFL  17 - 24
# 737  cases_10y_mean     2022          year      CHFL           CHFL  25 - 44
# 738  cases_10y_mean     2022          year      CHFL           CHFL  45 - 64
# 739  cases_10y_mean     2022          year      CHFL           CHFL      65+
# 740  cases_10y_mean     2022          year      CHFL           CHFL  unknown
# 741  cases_10y_mean     2023          year      CHFL           CHFL   0 - 16
# 742  cases_10y_mean     2023          year      CHFL           CHFL  17 - 24
# 743  cases_10y_mean     2023          year      CHFL           CHFL  25 - 44
# 744  cases_10y_mean     2023          year      CHFL           CHFL  45 - 64
# 745  cases_10y_mean     2023          year      CHFL           CHFL      65+
# 746  cases_10y_mean     2023          year      CHFL           CHFL  unknown
# 747  cases_10y_mean     2024          year      CHFL           CHFL   0 - 16
# 748  cases_10y_mean     2024          year      CHFL           CHFL  17 - 24
# 749  cases_10y_mean     2024          year      CHFL           CHFL  25 - 44
# 750  cases_10y_mean     2024          year      CHFL           CHFL  45 - 64
# 751  cases_10y_mean     2024          year      CHFL           CHFL      65+
# 752  cases_10y_mean     2024          year      CHFL           CHFL  unknown
# 753  cases_10y_mean     2025          year      CHFL           CHFL   0 - 16
# 754  cases_10y_mean     2025          year      CHFL           CHFL  17 - 24
# 755  cases_10y_mean     2025          year      CHFL           CHFL  25 - 44
# 756  cases_10y_mean     2025          year      CHFL           CHFL  45 - 64
# 757  cases_10y_mean     2025          year      CHFL           CHFL      65+
# 758  cases_10y_mean     2025          year      CHFL           CHFL  unknown
#
#      agegroup_type  sex type  value  ...  incValue  valueYearCumSum  \
# 735  agegroup_food  all  all    NaN  ...      9.62              NaN
# 736  agegroup_food  all  all    NaN  ...      6.17              NaN
# 737  agegroup_food  all  all    NaN  ...      5.39              NaN
# 738  agegroup_food  all  all    NaN  ...      5.73              NaN
# 739  agegroup_food  all  all    NaN  ...     11.69              NaN
# 740  agegroup_food  all  all    NaN  ...       NaN              NaN
# 741  agegroup_food  all  all    NaN  ...     10.87              NaN
# 742  agegroup_food  all  all    NaN  ...      7.45              NaN
# 743  agegroup_food  all  all    NaN  ...      6.33              NaN
# 744  agegroup_food  all  all    NaN  ...      6.82              NaN
# 745  agegroup_food  all  all    NaN  ...     13.72              NaN
# 746  agegroup_food  all  all    NaN  ...       NaN              NaN
# 747  agegroup_food  all  all    NaN  ...     12.28              NaN
# 748  agegroup_food  all  all    NaN  ...      8.85              NaN
# 749  agegroup_food  all  all    NaN  ...      7.42              NaN
# 750  agegroup_food  all  all    NaN  ...      7.83              NaN
# 751  agegroup_food  all  all    NaN  ...     15.99              NaN
# 752  agegroup_food  all  all    NaN  ...       NaN              NaN
# 753  agegroup_food  all  all    NaN  ...     13.23              NaN
# 754  agegroup_food  all  all    NaN  ...     10.14              NaN
# 755  agegroup_food  all  all    NaN  ...      8.34              NaN
# 756  agegroup_food  all  all    NaN  ...      8.99              NaN
# 757  agegroup_food  all  all    NaN  ...     17.91              NaN
# 758  agegroup_food  all  all    NaN  ...       NaN              NaN
#
#      valueMean3y  trend prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 735          NaN    NaN  NaN         NaN            NaN                 NaN
# 736          NaN    NaN  NaN         NaN            NaN                 NaN
# 737          NaN    NaN  NaN         NaN            NaN                 NaN
# 738          NaN    NaN  NaN         NaN            NaN                 NaN
# 739          NaN    NaN  NaN         NaN            NaN                 NaN
# 740          NaN    NaN  NaN         NaN            NaN                 NaN
# 741          NaN    NaN  NaN         NaN            NaN                 NaN
# 742          NaN    NaN  NaN         NaN            NaN                 NaN
# 743          NaN    NaN  NaN         NaN            NaN                 NaN
# 744          NaN    NaN  NaN         NaN            NaN                 NaN
# 745          NaN    NaN  NaN         NaN            NaN                 NaN
# 746          NaN    NaN  NaN         NaN            NaN                 NaN
# 747          NaN    NaN  NaN         NaN            NaN                 NaN
# 748          NaN    NaN  NaN         NaN            NaN                 NaN
# 749          NaN    NaN  NaN         NaN            NaN                 NaN
# 750          NaN    NaN  NaN         NaN            NaN                 NaN
# 751          NaN    NaN  NaN         NaN            NaN                 NaN
# 752          NaN    NaN  NaN         NaN            NaN                 NaN
# 753          NaN    NaN  NaN         NaN            NaN                 NaN
# 754          NaN    NaN  NaN         NaN            NaN                 NaN
# 755          NaN    NaN  NaN         NaN            NaN                 NaN
# 756          NaN    NaN  NaN         NaN            NaN                 NaN
# 757          NaN    NaN  NaN         NaN            NaN                 NaN
# 758          NaN    NaN  NaN         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 735          NaN          True
# 736          NaN          True
# 737          NaN          True
# 738          NaN          True
# 739          NaN          True
# 740          NaN          True
# 741          NaN          True
# 742          NaN          True
# 743          NaN          True
# 744          NaN          True
# 745          NaN          True
# 746          NaN          True
# 747          NaN          True
# 748          NaN          True
# 749          NaN          True
# 750          NaN          True
# 751          NaN          True
# 752          NaN          True
# 753          NaN          True
# 754          NaN          True
# 755          NaN          True
# 756          NaN          True
# 757          NaN          True
# 758          NaN          True
#
# [24 rows x 21 columns]

# %% [markdown]
# ### Datensatz für Geschlecht

# %%
data_sex = data[data["valueCategory"] == "cases_10y_cumsum"]

data_sex
# Out:
#         valueCategory temporal temporal_type georegion georegion_type  \
# 814  cases_10y_cumsum     2022          year      CHFL           CHFL
# 815  cases_10y_cumsum     2022          year      CHFL           CHFL
# 816  cases_10y_cumsum     2022          year      CHFL           CHFL
# 817  cases_10y_cumsum     2023          year      CHFL           CHFL
# 818  cases_10y_cumsum     2023          year      CHFL           CHFL
# 819  cases_10y_cumsum     2023          year      CHFL           CHFL
# 820  cases_10y_cumsum     2024          year      CHFL           CHFL
# 821  cases_10y_cumsum     2024          year      CHFL           CHFL
# 822  cases_10y_cumsum     2024          year      CHFL           CHFL
# 823  cases_10y_cumsum     2025          year      CHFL           CHFL
# 824  cases_10y_cumsum     2025          year      CHFL           CHFL
# 825  cases_10y_cumsum     2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex type   value  ...  incValue  \
# 814      all  agegroup_food   female  all  7169.0  ...       NaN
# 815      all  agegroup_food     male  all  7628.0  ...       NaN
# 816      all  agegroup_food  unknown  all    15.0  ...       NaN
# 817      all  agegroup_food   female  all  7444.0  ...       NaN
# 818      all  agegroup_food     male  all  7906.0  ...       NaN
# 819      all  agegroup_food  unknown  all    14.0  ...       NaN
# 820      all  agegroup_food   female  all  7985.0  ...       NaN
# 821      all  agegroup_food     male  all  8385.0  ...       NaN
# 822      all  agegroup_food  unknown  all    17.0  ...       NaN
# 823      all  agegroup_food   female  all  8402.0  ...       NaN
# 824      all  agegroup_food     male  all  8899.0  ...       NaN
# 825      all  agegroup_food  unknown  all    19.0  ...       NaN
#
#      valueYearCumSum  valueMean3y  trend  prct  deltaValue  deltaIncValue  \
# 814              NaN          NaN    NaN  48.4         NaN            NaN
# 815              NaN          NaN    NaN  51.5         NaN            NaN
# 816              NaN          NaN    NaN   0.1         NaN            NaN
# 817              NaN          NaN    NaN  48.5         NaN            NaN
# 818              NaN          NaN    NaN  51.5         NaN            NaN
# 819              NaN          NaN    NaN   0.1         NaN            NaN
# 820              NaN          NaN    NaN  48.7         NaN            NaN
# 821              NaN          NaN    NaN  51.2         NaN            NaN
# 822              NaN          NaN    NaN   0.1         NaN            NaN
# 823              NaN          NaN    NaN  48.5         NaN            NaN
# 824              NaN          NaN    NaN  51.4         NaN            NaN
# 825              NaN          NaN    NaN   0.1         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 814                 NaN          NaN          True
# 815                 NaN          NaN          True
# 816                 NaN          NaN          True
# 817                 NaN          NaN          True
# 818                 NaN          NaN          True
# 819                 NaN          NaN          True
# 820                 NaN          NaN          True
# 821                 NaN          NaN          True
# 822                 NaN          NaN          True
# 823                 NaN          NaN          True
# 824                 NaN          NaN          True
# 825                 NaN          NaN          True
#
# [12 rows x 21 columns]

# %% [markdown]
# ### Visuelle Analyse

# %%
# Ohne Kantone --> ~
data_cantons = data_def[~data_def["georegion"].isin(["CH", "CHFL"])]

#Gruppieren nach georegion und Werte summieren
counts = (
    data_cantons.groupby("georegion")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_georegion = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("sum_value", title="Total Cases")
).properties(
    title="EHEC Georegion 2013-2025"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)

# %%
#Gruppieren nach georegion und Werte summieren
counts = (
    data_def.groupby("temporal")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_temporal = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("temporal", title="Temporal"),
    y=alt.Y("sum_value", title="Cases")
).properties(
    title="EHEC Temporal"
)

# Textlabels
text = bar_temporal.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_temporal = bar_temporal + text
bar_temporal
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * Datensatz aufteilen in monatlich und Jährlich

# %%
data_1 = data_def.copy()

data_year = data_1[data_1["temporal_type"] == "year"]

data_year
# Out:
#     valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 332         cases     2013          year        AG         canton      all
# 333         cases     2013          year        AI         canton      all
# 334         cases     2013          year        AR         canton      all
# 335         cases     2013          year        BE         canton      all
# 336         cases     2013          year        BL         canton      all
# ..            ...      ...           ...       ...            ...      ...
# 730         cases     2023          year      CHFL           CHFL      all
# 731         cases     2024          year      CHFL           CHFL      all
# 732         cases     2024          year      CHFL           CHFL      all
# 733         cases     2025          year      CHFL           CHFL      all
# 734         cases     2025          year      CHFL           CHFL      all
#
#      agegroup_type  sex     type   value  ...  incValue  valueYearCumSum  \
# 332  agegroup_food  all      all     9.0  ...      1.41              NaN
# 333  agegroup_food  all      all     0.0  ...      0.00              NaN
# 334  agegroup_food  all      all     0.0  ...      0.00              NaN
# 335  agegroup_food  all      all    13.0  ...      1.30              NaN
# 336  agegroup_food  all      all     6.0  ...      2.15              NaN
# ..             ...  ...      ...     ...  ...       ...              ...
# 730  agegroup_food  all  non-hus  1217.0  ...     13.52              NaN
# 731  agegroup_food  all      hus    24.0  ...      0.26              NaN
# 732  agegroup_food  all  non-hus  1368.0  ...     15.05              NaN
# 733  agegroup_food  all      hus    23.0  ...      0.25              NaN
# 734  agegroup_food  all  non-hus  1423.0  ...     15.65              NaN
#
#      valueMean3y  trend  prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 332          NaN    NaN  11.0         NaN            NaN                 NaN
# 333          NaN    NaN   0.0         NaN            NaN                 NaN
# 334          NaN    NaN   0.0         NaN            NaN                 NaN
# 335          NaN    NaN  15.9         NaN            NaN                 NaN
# 336          NaN    NaN   7.3         NaN            NaN                 NaN
# ..           ...    ...   ...         ...            ...                 ...
# 730       1105.3    NaN  98.2         NaN            NaN                 NaN
# 731         23.3    NaN   1.7         NaN            NaN                 NaN
# 732       1255.3    NaN  98.3         NaN            NaN                 NaN
# 733         23.0    NaN   1.6         NaN            NaN                 NaN
# 734       1336.0    NaN  98.4         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 332          NaN          True
# 333          NaN          True
# 334          NaN          True
# 335          NaN          True
# 336          NaN          True
# ..           ...           ...
# 730          NaN          True
# 731          NaN          True
# 732          NaN          True
# 733          NaN          True
# 734          NaN          True
#
# [403 rows x 21 columns]

# %%
# Ohne Kantone
data_year_CH = data_year[data_year["georegion"].isin(["CH", "CHFL"])]

bar_year = alt.Chart(data_year_CH).mark_bar().encode(
    x=alt.X("temporal", title="Temporal"),
    y=alt.Y("value", title="Cases"),
    color=alt.Color("incValue")
).properties(
    title="EHEC Year"
)

bar_year
# Out:
# alt.Chart(...)

# %%
data_2 = data_def.copy()

data_month = data_2[data_2["temporal_type"] == "month"]

data_month
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 159         cases  2026-M04         month      CHFL           CHFL      all
# 160         cases  2026-M05         month      CHFL           CHFL      all
# 161         cases  2026-M06         month      CHFL           CHFL      all
# 162         cases  2026-M07         month      CHFL           CHFL      all
# 163         cases  2026-M08         month      CHFL           CHFL      all
#
#      agegroup_type  sex type  value  ...  incValue  valueYearCumSum  \
# 0    agegroup_food  all  all    2.0  ...      0.02              2.0
# 1    agegroup_food  all  all    0.0  ...      0.00              2.0
# 2    agegroup_food  all  all    6.0  ...      0.07              8.0
# 3    agegroup_food  all  all    8.0  ...      0.10             16.0
# 4    agegroup_food  all  all    6.0  ...      0.07             22.0
# ..             ...  ...  ...    ...  ...       ...              ...
# 159  agegroup_food  all  all  112.0  ...      1.23            406.0
# 160  agegroup_food  all  all  138.0  ...      1.52            544.0
# 161  agegroup_food  all  all  165.0  ...      1.81            709.0
# 162  agegroup_food  all  all  267.0  ...      2.94            976.0
# 163  agegroup_food  all  all  261.0  ...      2.87           1237.0
#
#      valueMean3y     trend prct  deltaValue  deltaIncValue  \
# 0            NaN       NaN  NaN         NaN            NaN
# 1            NaN       NaN  NaN         NaN            NaN
# 2            NaN       NaN  NaN         NaN            NaN
# 3            NaN    rising  NaN         NaN            NaN
# 4            NaN  stagnant  NaN         NaN            NaN
# ..           ...       ...  ...         ...            ...
# 159          NaN  stagnant  NaN         NaN            NaN
# 160          NaN    rising  NaN         NaN            NaN
# 161          NaN    rising  NaN         NaN            NaN
# 162          NaN    rising  NaN         NaN            NaN
# 163          NaN    rising  NaN         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 159                 NaN          NaN          True
# 160                 NaN          NaN          True
# 161                 NaN          NaN          True
# 162                 NaN          NaN          True
# 163                 NaN          NaN          True
#
# [164 rows x 21 columns]

# %%
bar_month = alt.Chart(data_month).mark_bar().encode(
    x=alt.X("temporal:N", title="Temporal"),
    y=alt.Y("value:Q", title="Cases"),
    color=alt.Color("trend:N")
).properties(
    title="EHEC Month"
)

bar_month
# Out:
# alt.Chart(...)

# %%
bar_age = alt.Chart(data_med).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases"),
    color=alt.Color("temporal")
).properties(
    title="Salmonellosis Altersgruppen 2022 - 2025"
)

bar_age
# Out:
# alt.Chart(...)

# %%
data_age_2025 = data_med[data_med["temporal"] == "2025"]

bar_age_2 = alt.Chart(data_age_2025).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases")
).properties(
    title="Salmonellosis Altersgruppen 2025"
)

bar_age_2
# Out:
# alt.Chart(...)
