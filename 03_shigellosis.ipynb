# %% [markdown]
# # Share 5 - BAG
# ## Shigellose
# * Übersicht: https://www.idd.bag.admin.ch/de/diseases/shigellosis/overview
# * Daten: https://www.idd.bag.admin.ch/de/diseases/shigellosis/data
#
# Werden monatlich geupdatet
#
# Obligatorische Meldung

# %%
# Importieren der Libraries

# Daten-Analyse
import pandas as pd

# Daten-Visualisierung
import altair as alt

# %% [markdown]
# ### Daten hereinladen

# %%
# Daten laden --> read_csv / read_excel
# Falls mehrere sheets --> sheet_name="sheet"


data = pd.read_csv("data/shigellosis/data.csv")

data
# Out:
#         valueCategory  temporal temporal_type georegion georegion_type  \
# 0               cases  2013-M01         month      CHFL           CHFL
# 1               cases  2013-M02         month      CHFL           CHFL
# 2               cases  2013-M03         month      CHFL           CHFL
# 3               cases  2013-M04         month      CHFL           CHFL
# 4               cases  2013-M05         month      CHFL           CHFL
# ..                ...       ...           ...       ...            ...
# 740  cases_10y_cumsum      2024          year      CHFL           CHFL
# 741  cases_10y_cumsum      2024          year      CHFL           CHFL
# 742  cases_10y_cumsum      2025          year      CHFL           CHFL
# 743  cases_10y_cumsum      2025          year      CHFL           CHFL
# 744  cases_10y_cumsum      2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex   value        pop  incValue  \
# 0        all  agegroup_food      all    15.0  8176573.0      0.18
# 1        all  agegroup_food      all    11.0  8176573.0      0.13
# 2        all  agegroup_food      all    13.0  8176573.0      0.16
# 3        all  agegroup_food      all    12.0  8176573.0      0.15
# 4        all  agegroup_food      all     4.0  8176573.0      0.05
# ..       ...            ...      ...     ...        ...       ...
# 740      all  agegroup_food     male   979.0        NaN       NaN
# 741      all  agegroup_food  unknown     2.0        NaN       NaN
# 742      all  agegroup_food   female   748.0        NaN       NaN
# 743      all  agegroup_food     male  1007.0        NaN       NaN
# 744      all  agegroup_food  unknown     2.0        NaN       NaN
#
#      valueYearCumSum  valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0               15.0          NaN       NaN   NaN         NaN            NaN
# 1               26.0          NaN       NaN   NaN         NaN            NaN
# 2               39.0          NaN       NaN   NaN         NaN            NaN
# 3               51.0          NaN  stagnant   NaN         NaN            NaN
# 4               55.0          NaN  stagnant   NaN         NaN            NaN
# ..               ...          ...       ...   ...         ...            ...
# 740              NaN          NaN       NaN  57.5         NaN            NaN
# 741              NaN          NaN       NaN   0.1         NaN            NaN
# 742              NaN          NaN       NaN  42.6         NaN            NaN
# 743              NaN          NaN       NaN  57.3         NaN            NaN
# 744              NaN          NaN       NaN   0.1         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 740                 NaN          NaN          True
# 741                 NaN          NaN          True
# 742                 NaN          NaN          True
# 743                 NaN          NaN          True
# 744                 NaN          NaN          True
#
# [745 rows x 20 columns]

# %% [markdown]
# ### Variablen

# %%
data.columns
# Out:
# Index(['valueCategory', 'temporal', 'temporal_type', 'georegion',
#        'georegion_type', 'agegroup', 'agegroup_type', 'sex', 'value', 'pop',
#        'incValue', 'valueYearCumSum', 'valueMean3y', 'trend', 'prct',
#        'deltaValue', 'deltaIncValue', 'incValuePrctChange', 'valueMean5y',
#        'dataComplete'],
#       dtype='object')

# %% [markdown]
# * valueCategory: Was gemessen wird --> Hier: Anzahl gemeldete Fälle
# * temporal: Welcher Zeitabschnitt --> Jahr und Monat
# * temporal_type: Typ der Zeit --> Monat
# * georegion: Kanton oder Land --> hier Anfang Land später Kanton
# * georegion_type: Typ der Georegion --> Land/Kantonal
# * agegroup: Alterskategorie
# * agegroup_type: Zuordnung zur Oberthema --> bei allen gleich
# * sex: Geschlecht
# * value: Wert basierend auf vorhergehende Kategorien
# * pop: Bevölkerung zum Zeitpunkt der Erhebung
# * incValue: neuaufgetrettene Fälle innerhalb der Gruppe und Zeit
# * valueYearCumSum: Gesamter Wert über das Jahr
# * valueMean3y: Durchschnittswert der letzten drei Jahre
# * trend: ist der Trend abnehmend(falling), gleich(stagnant) oder steigend(rising)
# * prct: prozentualer Anteil der Fälle in den Kategorien und Zeiteinheit
# * deltaValue: Unterschied des value zum vorherigen Wert
# * deltaIncValue: Unterschied des incValue zum vorherigen Wert
# * incValuePrctChange: Prozentualer Unterschied zum vorherigen Wert
# * valueMean5y: Durchschnittlicher Wert der letzten 5 Jahre
# * dataComplete: ist dieser Datenpunkt komplett

# %%
data.dtypes
# Out:
# valueCategory          object
# temporal               object
# temporal_type          object
# georegion              object
# georegion_type         object
# agegroup               object
# agegroup_type          object
# sex                    object
# value                 float64
# pop                   float64
# incValue              float64
# valueYearCumSum       float64
# valueMean3y           float64
# trend                  object
# prct                  float64
# deltaValue            float64
# deltaIncValue         float64
# incValuePrctChange    float64
# valueMean5y           float64
# dataComplete             bool
# dtype: object

# %% [markdown]
# ### Datensatz für Cases
#
# --> Die Durchschnittswerte sind als Einzelne Datenpunkte erhoben

# %%
data_def = data[data["valueCategory"] == "cases"]

data_def
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 704         cases      2025          year        UR         canton      all
# 705         cases      2025          year        VD         canton      all
# 706         cases      2025          year        VS         canton      all
# 707         cases      2025          year        ZG         canton      all
# 708         cases      2025          year        ZH         canton      all
#
#      agegroup_type  sex  value        pop  incValue  valueYearCumSum  \
# 0    agegroup_food  all   15.0  8176573.0      0.18             15.0
# 1    agegroup_food  all   11.0  8176573.0      0.13             26.0
# 2    agegroup_food  all   13.0  8176573.0      0.16             39.0
# 3    agegroup_food  all   12.0  8176573.0      0.15             51.0
# 4    agegroup_food  all    4.0  8176573.0      0.05             55.0
# ..             ...  ...    ...        ...       ...              ...
# 704  agegroup_food  all    0.0    38275.0      0.00              NaN
# 705  agegroup_food  all   37.0   855106.0      4.33              NaN
# 706  agegroup_food  all   10.0   371288.0      2.69              NaN
# 707  agegroup_food  all    4.0   133739.0      2.99              NaN
# 708  agegroup_food  all   37.0  1620020.0      2.28              NaN
#
#      valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0            NaN       NaN   NaN         NaN            NaN
# 1            NaN       NaN   NaN         NaN            NaN
# 2            NaN       NaN   NaN         NaN            NaN
# 3            NaN  stagnant   NaN         NaN            NaN
# 4            NaN  stagnant   NaN         NaN            NaN
# ..           ...       ...   ...         ...            ...
# 704          0.3       NaN   0.0         NaN            NaN
# 705         34.0       NaN  15.9         NaN            NaN
# 706          7.3       NaN   4.3         NaN            NaN
# 707          4.7       NaN   1.7         NaN            NaN
# 708         37.0       NaN  15.9         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 704                 NaN          NaN          True
# 705                 NaN          NaN          True
# 706                 NaN          NaN          True
# 707                 NaN          NaN          True
# 708                 NaN          NaN          True
#
# [541 rows x 20 columns]

# %% [markdown]
# ### Datensatz für Agegroup

# %%
data_med = data[data["valueCategory"] == "cases_10y_mean"]

data_med
# Out:
#       valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 709  cases_10y_mean     2022          year      CHFL           CHFL   0 - 16
# 710  cases_10y_mean     2022          year      CHFL           CHFL  17 - 24
# 711  cases_10y_mean     2022          year      CHFL           CHFL  25 - 44
# 712  cases_10y_mean     2022          year      CHFL           CHFL  45 - 64
# 713  cases_10y_mean     2022          year      CHFL           CHFL      65+
# 714  cases_10y_mean     2022          year      CHFL           CHFL  unknown
# 715  cases_10y_mean     2023          year      CHFL           CHFL   0 - 16
# 716  cases_10y_mean     2023          year      CHFL           CHFL  17 - 24
# 717  cases_10y_mean     2023          year      CHFL           CHFL  25 - 44
# 718  cases_10y_mean     2023          year      CHFL           CHFL  45 - 64
# 719  cases_10y_mean     2023          year      CHFL           CHFL      65+
# 720  cases_10y_mean     2023          year      CHFL           CHFL  unknown
# 721  cases_10y_mean     2024          year      CHFL           CHFL   0 - 16
# 722  cases_10y_mean     2024          year      CHFL           CHFL  17 - 24
# 723  cases_10y_mean     2024          year      CHFL           CHFL  25 - 44
# 724  cases_10y_mean     2024          year      CHFL           CHFL  45 - 64
# 725  cases_10y_mean     2024          year      CHFL           CHFL      65+
# 726  cases_10y_mean     2024          year      CHFL           CHFL  unknown
# 727  cases_10y_mean     2025          year      CHFL           CHFL   0 - 16
# 728  cases_10y_mean     2025          year      CHFL           CHFL  17 - 24
# 729  cases_10y_mean     2025          year      CHFL           CHFL  25 - 44
# 730  cases_10y_mean     2025          year      CHFL           CHFL  45 - 64
# 731  cases_10y_mean     2025          year      CHFL           CHFL      65+
# 732  cases_10y_mean     2025          year      CHFL           CHFL  unknown
#
#      agegroup_type  sex  value  pop  incValue  valueYearCumSum  valueMean3y  \
# 709  agegroup_food  all    NaN  NaN      1.23              NaN          NaN
# 710  agegroup_food  all    NaN  NaN      2.16              NaN          NaN
# 711  agegroup_food  all    NaN  NaN      2.82              NaN          NaN
# 712  agegroup_food  all    NaN  NaN      1.96              NaN          NaN
# 713  agegroup_food  all    NaN  NaN      0.81              NaN          NaN
# 714  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
# 715  agegroup_food  all    NaN  NaN      1.18              NaN          NaN
# 716  agegroup_food  all    NaN  NaN      2.09              NaN          NaN
# 717  agegroup_food  all    NaN  NaN      2.94              NaN          NaN
# 718  agegroup_food  all    NaN  NaN      1.99              NaN          NaN
# 719  agegroup_food  all    NaN  NaN      0.81              NaN          NaN
# 720  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
# 721  agegroup_food  all    NaN  NaN      1.14              NaN          NaN
# 722  agegroup_food  all    NaN  NaN      2.03              NaN          NaN
# 723  agegroup_food  all    NaN  NaN      3.11              NaN          NaN
# 724  agegroup_food  all    NaN  NaN      2.01              NaN          NaN
# 725  agegroup_food  all    NaN  NaN      0.86              NaN          NaN
# 726  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
# 727  agegroup_food  all    NaN  NaN      1.16              NaN          NaN
# 728  agegroup_food  all    NaN  NaN      2.10              NaN          NaN
# 729  agegroup_food  all    NaN  NaN      3.25              NaN          NaN
# 730  agegroup_food  all    NaN  NaN      1.98              NaN          NaN
# 731  agegroup_food  all    NaN  NaN      0.86              NaN          NaN
# 732  agegroup_food  all    NaN  NaN       NaN              NaN          NaN
#
#     trend  prct  deltaValue  deltaIncValue  incValuePrctChange  valueMean5y  \
# 709   NaN   NaN         NaN            NaN                 NaN          NaN
# 710   NaN   NaN         NaN            NaN                 NaN          NaN
# 711   NaN   NaN         NaN            NaN                 NaN          NaN
# 712   NaN   NaN         NaN            NaN                 NaN          NaN
# 713   NaN   NaN         NaN            NaN                 NaN          NaN
# 714   NaN   NaN         NaN            NaN                 NaN          NaN
# 715   NaN   NaN         NaN            NaN                 NaN          NaN
# 716   NaN   NaN         NaN            NaN                 NaN          NaN
# 717   NaN   NaN         NaN            NaN                 NaN          NaN
# 718   NaN   NaN         NaN            NaN                 NaN          NaN
# 719   NaN   NaN         NaN            NaN                 NaN          NaN
# 720   NaN   NaN         NaN            NaN                 NaN          NaN
# 721   NaN   NaN         NaN            NaN                 NaN          NaN
# 722   NaN   NaN         NaN            NaN                 NaN          NaN
# 723   NaN   NaN         NaN            NaN                 NaN          NaN
# 724   NaN   NaN         NaN            NaN                 NaN          NaN
# 725   NaN   NaN         NaN            NaN                 NaN          NaN
# 726   NaN   NaN         NaN            NaN                 NaN          NaN
# 727   NaN   NaN         NaN            NaN                 NaN          NaN
# 728   NaN   NaN         NaN            NaN                 NaN          NaN
# 729   NaN   NaN         NaN            NaN                 NaN          NaN
# 730   NaN   NaN         NaN            NaN                 NaN          NaN
# 731   NaN   NaN         NaN            NaN                 NaN          NaN
# 732   NaN   NaN         NaN            NaN                 NaN          NaN
#
#      dataComplete
# 709          True
# 710          True
# 711          True
# 712          True
# 713          True
# 714          True
# 715          True
# 716          True
# 717          True
# 718          True
# 719          True
# 720          True
# 721          True
# 722          True
# 723          True
# 724          True
# 725          True
# 726          True
# 727          True
# 728          True
# 729          True
# 730          True
# 731          True
# 732          True

# %%
# Exportieren des Datensatzes für Fälle pro Altersklasse
# data_med.to_csv("./export/data_shigellosis_fälle_altersklasse.csv", index=False)

# %% [markdown]
# ### Datensatz für Geschlecht

# %%
data_sex = data[data["valueCategory"] == "cases_10y_cumsum"]

data_sex
# Out:
#         valueCategory temporal temporal_type georegion georegion_type  \
# 733  cases_10y_cumsum     2022          year      CHFL           CHFL
# 734  cases_10y_cumsum     2022          year      CHFL           CHFL
# 735  cases_10y_cumsum     2022          year      CHFL           CHFL
# 736  cases_10y_cumsum     2023          year      CHFL           CHFL
# 737  cases_10y_cumsum     2023          year      CHFL           CHFL
# 738  cases_10y_cumsum     2023          year      CHFL           CHFL
# 739  cases_10y_cumsum     2024          year      CHFL           CHFL
# 740  cases_10y_cumsum     2024          year      CHFL           CHFL
# 741  cases_10y_cumsum     2024          year      CHFL           CHFL
# 742  cases_10y_cumsum     2025          year      CHFL           CHFL
# 743  cases_10y_cumsum     2025          year      CHFL           CHFL
# 744  cases_10y_cumsum     2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex   value  pop  incValue  valueYearCumSum  \
# 733      all  agegroup_food   female   704.0  NaN       NaN              NaN
# 734      all  agegroup_food     male   897.0  NaN       NaN              NaN
# 735      all  agegroup_food  unknown     3.0  NaN       NaN              NaN
# 736      all  agegroup_food   female   695.0  NaN       NaN              NaN
# 737      all  agegroup_food     male   947.0  NaN       NaN              NaN
# 738      all  agegroup_food  unknown     4.0  NaN       NaN              NaN
# 739      all  agegroup_food   female   723.0  NaN       NaN              NaN
# 740      all  agegroup_food     male   979.0  NaN       NaN              NaN
# 741      all  agegroup_food  unknown     2.0  NaN       NaN              NaN
# 742      all  agegroup_food   female   748.0  NaN       NaN              NaN
# 743      all  agegroup_food     male  1007.0  NaN       NaN              NaN
# 744      all  agegroup_food  unknown     2.0  NaN       NaN              NaN
#
#      valueMean3y trend  prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 733          NaN   NaN  43.9         NaN            NaN                 NaN
# 734          NaN   NaN  55.9         NaN            NaN                 NaN
# 735          NaN   NaN   0.2         NaN            NaN                 NaN
# 736          NaN   NaN  42.2         NaN            NaN                 NaN
# 737          NaN   NaN  57.5         NaN            NaN                 NaN
# 738          NaN   NaN   0.2         NaN            NaN                 NaN
# 739          NaN   NaN  42.4         NaN            NaN                 NaN
# 740          NaN   NaN  57.5         NaN            NaN                 NaN
# 741          NaN   NaN   0.1         NaN            NaN                 NaN
# 742          NaN   NaN  42.6         NaN            NaN                 NaN
# 743          NaN   NaN  57.3         NaN            NaN                 NaN
# 744          NaN   NaN   0.1         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 733          NaN          True
# 734          NaN          True
# 735          NaN          True
# 736          NaN          True
# 737          NaN          True
# 738          NaN          True
# 739          NaN          True
# 740          NaN          True
# 741          NaN          True
# 742          NaN          True
# 743          NaN          True
# 744          NaN          True

# %%
# Exportieren des Datensatzes für Fälle Geschlechterverteilung
# data_sex.to_csv("./export/data_shigellosis_fälle_geschlecht.csv", index=False)

# %% [markdown]
# ### Visuelle Analyse

# %%
# Ohne Kantone --> ~
data_cantons = data_def[~data_def["georegion"].isin(["CH", "CHFL"])]

#Gruppieren nach georegion und Werte summieren
counts = (
    data_cantons.groupby("georegion")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_georegion = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("sum_value", title="Total Cases")
).properties(
    title="Shigellosis Georegion 2013-2025"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * ZH am höchsten --> grösster Kanton
# * kleine Kantone --> weniger Fälle

# %%
# nur 2025
data_cantons_2025 = data_cantons[data_cantons["temporal"] == "2025"]

#Gruppieren nach georegion und Werte summieren
counts = (
    data_cantons_2025.groupby("georegion")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_georegion_2025 = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("sum_value", title="Total Cases")
).properties(
    title="Shigellosis Georegion 2025"
)

# Textlabels
text = bar_georegion_2025.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_georegion_2025 = bar_georegion_2025 + text
bar_georegion_2025
# Out:
# alt.LayerChart(...)

# %%
data_1 = data_def.copy()

data_year = data_1[data_1["temporal_type"] == "year"]

data_year
# Out:
#     valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 332         cases     2013          year        AG         canton      all
# 333         cases     2013          year        AI         canton      all
# 334         cases     2013          year        AR         canton      all
# 335         cases     2013          year        BE         canton      all
# 336         cases     2013          year        BL         canton      all
# ..            ...      ...           ...       ...            ...      ...
# 704         cases     2025          year        UR         canton      all
# 705         cases     2025          year        VD         canton      all
# 706         cases     2025          year        VS         canton      all
# 707         cases     2025          year        ZG         canton      all
# 708         cases     2025          year        ZH         canton      all
#
#      agegroup_type  sex  value        pop  incValue  valueYearCumSum  \
# 332  agegroup_food  all   11.0   636362.0      1.73              NaN
# 333  agegroup_food  all    0.0    15778.0      0.00              NaN
# 334  agegroup_food  all    0.0    53691.0      0.00              NaN
# 335  agegroup_food  all    9.0  1001281.0      0.90              NaN
# 336  agegroup_food  all    7.0   278656.0      2.51              NaN
# ..             ...  ...    ...        ...       ...              ...
# 704  agegroup_food  all    0.0    38275.0      0.00              NaN
# 705  agegroup_food  all   37.0   855106.0      4.33              NaN
# 706  agegroup_food  all   10.0   371288.0      2.69              NaN
# 707  agegroup_food  all    4.0   133739.0      2.99              NaN
# 708  agegroup_food  all   37.0  1620020.0      2.28              NaN
#
#      valueMean3y trend  prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 332          NaN   NaN   7.5         NaN            NaN                 NaN
# 333          NaN   NaN   0.0         NaN            NaN                 NaN
# 334          NaN   NaN   0.0         NaN            NaN                 NaN
# 335          NaN   NaN   6.1         NaN            NaN                 NaN
# 336          NaN   NaN   4.8         NaN            NaN                 NaN
# ..           ...   ...   ...         ...            ...                 ...
# 704          0.3   NaN   0.0         NaN            NaN                 NaN
# 705         34.0   NaN  15.9         NaN            NaN                 NaN
# 706          7.3   NaN   4.3         NaN            NaN                 NaN
# 707          4.7   NaN   1.7         NaN            NaN                 NaN
# 708         37.0   NaN  15.9         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 332          NaN          True
# 333          NaN          True
# 334          NaN          True
# 335          NaN          True
# 336          NaN          True
# ..           ...           ...
# 704          NaN          True
# 705          NaN          True
# 706          NaN          True
# 707          NaN          True
# 708          NaN          True
#
# [377 rows x 20 columns]

# %%
# Exportieren des Datensatzes für Fälle pro Kanton
# data_year.to_csv("./export/data_shigellosis_fälle_georegion.csv", index=False)

# %%
# Ohne Kantone
data_year_CH = data_year[data_year["georegion"].isin(["CH"])]

bar_year = alt.Chart(data_year_CH).mark_bar().encode(
    x=alt.X("temporal", title="Temporal"),
    y=alt.Y("value", title="Cases")
).properties(
    title="Shigellosis Year"
)

# Textlabels
text = bar_year.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_year = bar_year + text
bar_year
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * Steigende Fallzahlen in den letzten Jahren

# %%
data_2 = data_def.copy()

data_month = data_2[data_2["temporal_type"] == "month"]

data_month
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 159         cases  2026-M04         month      CHFL           CHFL      all
# 160         cases  2026-M05         month      CHFL           CHFL      all
# 161         cases  2026-M06         month      CHFL           CHFL      all
# 162         cases  2026-M07         month      CHFL           CHFL      all
# 163         cases  2026-M08         month      CHFL           CHFL      all
#
#      agegroup_type  sex  value        pop  incValue  valueYearCumSum  \
# 0    agegroup_food  all   15.0  8176573.0      0.18             15.0
# 1    agegroup_food  all   11.0  8176573.0      0.13             26.0
# 2    agegroup_food  all   13.0  8176573.0      0.16             39.0
# 3    agegroup_food  all   12.0  8176573.0      0.15             51.0
# 4    agegroup_food  all    4.0  8176573.0      0.05             55.0
# ..             ...  ...    ...        ...       ...              ...
# 159  agegroup_food  all   17.0  9091674.0      0.19             70.0
# 160  agegroup_food  all   18.0  9091674.0      0.20             88.0
# 161  agegroup_food  all   23.0  9091674.0      0.25            111.0
# 162  agegroup_food  all   23.0  9091674.0      0.25            134.0
# 163  agegroup_food  all   27.0  9091674.0      0.30            161.0
#
#      valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0            NaN       NaN   NaN         NaN            NaN
# 1            NaN       NaN   NaN         NaN            NaN
# 2            NaN       NaN   NaN         NaN            NaN
# 3            NaN  stagnant   NaN         NaN            NaN
# 4            NaN  stagnant   NaN         NaN            NaN
# ..           ...       ...   ...         ...            ...
# 159          NaN  stagnant   NaN         NaN            NaN
# 160          NaN  stagnant   NaN         NaN            NaN
# 161          NaN  stagnant   NaN         NaN            NaN
# 162          NaN  stagnant   NaN         NaN            NaN
# 163          NaN  stagnant   NaN         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 159                 NaN          NaN          True
# 160                 NaN          NaN          True
# 161                 NaN          NaN          True
# 162                 NaN          NaN          True
# 163                 NaN          NaN          True
#
# [164 rows x 20 columns]

# %%
# Exportieren des Datensatzes für Fälle pro Monat
# data_month.to_csv("./export/data_shigellosis_fälle_monat.csv", index=False)

# %%
#Gruppieren nach Jahren und Werte summieren


bar_month = alt.Chart(data_month).mark_bar().encode(
    x=alt.X("temporal:N", title="Temporal"),
    y=alt.Y("value:Q", title="Cases"),
    color=alt.Color("trend:N")
).properties(
    title="Shigellosis Month"
)

# Textlabels
text = bar_month.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_month = bar_month + text
bar_month
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * im Sommer am Höchsten¨
# * im Winter tiefer
# * steigende Zahlen in den letzten Jahren

# %%
bar_age = alt.Chart(data_med).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases"),
    color=alt.Color("temporal")
).properties(
    title="Shigellosis Altersgruppen 2022 - 2025"
)

bar_age
# Out:
# alt.Chart(...)

# %%
data_age_2025 = data_med[data_med["temporal"] == "2025"]

bar_age_2 = alt.Chart(data_age_2025).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases")
).properties(
    title="Shigellosis Altersgruppen 2025"
)

# Textlabels
text = bar_age_2.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="incValue:Q"
)

bar_age_2 = bar_age_2 + text

bar_age_2
# Out:
# alt.LayerChart(...)

# %%
bar_sex = alt.Chart(data_sex).mark_bar().encode(
    x=alt.X("sex", title="Sex"),
    y=alt.Y("value", title="Cases"),
    color=alt.Color("temporal")
).properties(
    title="Shigellosis Geschlechterverteilung 2022 - 2025"
)

bar_sex
# Out:
# alt.Chart(...)

# %%
data_sex_2025 = data_sex[data_sex["temporal"] == "2025"]

bar_sex_2 = alt.Chart(data_sex_2025).mark_bar().encode(
    x=alt.X("sex", title="Geschlecht"),
    y=alt.Y("value", title="Cases")
).properties(
    title="Shigellosis Geschlechterverteilung 2025"
)

# Textlabels
text = bar_sex_2.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_sex_2 = bar_sex_2 + text
bar_sex_2
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Durchschnittsberechnungen & -visualisierungen

# %%
# Ohne Kantone --> ~
data_cantons = data_def[~data_def["georegion"].isin(["CH", "CHFL"])]

#Gruppieren nach georegion und Werte summieren
counts_mean = (
    data_cantons.groupby("georegion")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

#Bar Chart
bar_georegion = alt.Chart(counts_mean).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("mean_value", title="Mean Cases")
).properties(
    title="Shigellosis Georegion 2013-2025 Mean"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)

# %%
# Jahr und Monat trennen
data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)

data_month
# Out:
# /var/folders/wr/rgnzqf8x4w501ytwkhks5qfw0000gn/T/ipykernel_27615/2880901401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)
# /var/folders/wr/rgnzqf8x4w501ytwkhks5qfw0000gn/T/ipykernel_27615/2880901401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 159         cases  2026-M04         month      CHFL           CHFL      all
# 160         cases  2026-M05         month      CHFL           CHFL      all
# 161         cases  2026-M06         month      CHFL           CHFL      all
# 162         cases  2026-M07         month      CHFL           CHFL      all
# 163         cases  2026-M08         month      CHFL           CHFL      all
#
#      agegroup_type  sex  value        pop  ...  valueMean3y     trend  prct  \
# 0    agegroup_food  all   15.0  8176573.0  ...          NaN       NaN   NaN
# 1    agegroup_food  all   11.0  8176573.0  ...          NaN       NaN   NaN
# 2    agegroup_food  all   13.0  8176573.0  ...          NaN       NaN   NaN
# 3    agegroup_food  all   12.0  8176573.0  ...          NaN  stagnant   NaN
# 4    agegroup_food  all    4.0  8176573.0  ...          NaN  stagnant   NaN
# ..             ...  ...    ...        ...  ...          ...       ...   ...
# 159  agegroup_food  all   17.0  9091674.0  ...          NaN  stagnant   NaN
# 160  agegroup_food  all   18.0  9091674.0  ...          NaN  stagnant   NaN
# 161  agegroup_food  all   23.0  9091674.0  ...          NaN  stagnant   NaN
# 162  agegroup_food  all   23.0  9091674.0  ...          NaN  stagnant   NaN
# 163  agegroup_food  all   27.0  9091674.0  ...          NaN  stagnant   NaN
#
#     deltaValue  deltaIncValue  incValuePrctChange  valueMean5y  dataComplete  \
# 0          NaN            NaN                 NaN          NaN          True
# 1          NaN            NaN                 NaN          NaN          True
# 2          NaN            NaN                 NaN          NaN          True
# 3          NaN            NaN                 NaN          NaN          True
# 4          NaN            NaN                 NaN          NaN          True
# ..         ...            ...                 ...          ...           ...
# 159        NaN            NaN                 NaN          NaN          True
# 160        NaN            NaN                 NaN          NaN          True
# 161        NaN            NaN                 NaN          NaN          True
# 162        NaN            NaN                 NaN          NaN          True
# 163        NaN            NaN                 NaN          NaN          True
#
#      year  month
# 0    2013    M01
# 1    2013    M02
# 2    2013    M03
# 3    2013    M04
# 4    2013    M05
# ..    ...    ...
# 159  2026    M04
# 160  2026    M05
# 161  2026    M06
# 162  2026    M07
# 163  2026    M08
#
# [164 rows x 22 columns]

# %%
counts_mean = (
    data_month.groupby("month")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

bar_month = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("month:N", title="Month"),
    y=alt.Y("mean_value:Q", title="Cases")
).properties(
    title="Shigellosis Month 2013-2026 Mean"
)

# Textlabels
text = bar_month.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_month = bar_month + text
bar_month
# Out:
# alt.LayerChart(...)

# %%
counts_mean = (
    data_med.groupby("agegroup")
        .agg(mean_value=("incValue", "mean")).round(0)
        .reset_index()
)

bar_age = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("mean_value", title="Cases")
).properties(
    title="Shigellosis Altersgruppen 2022 - 2025 Mean IncValue"
)

# Textlabels
text = bar_age.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_age = bar_age + text
bar_age
# Out:
# alt.LayerChart(...)

# %%
counts_mean = (
    data_sex.groupby("sex")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

bar_sex = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("sex", title="Sex"),
    y=alt.Y("mean_value", title="Cases")
).properties(
    title="Shigellosis Geschlechterverteilung 2022 - 2025 Mean"
)

# Textlabels
text = bar_sex.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_sex = bar_sex + text
bar_sex

bar_sex
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Auf 100'000 Personen gerechnet

# %%
data_cantons
# Out:
#     valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 332         cases     2013          year        AG         canton      all
# 333         cases     2013          year        AI         canton      all
# 334         cases     2013          year        AR         canton      all
# 335         cases     2013          year        BE         canton      all
# 336         cases     2013          year        BL         canton      all
# ..            ...      ...           ...       ...            ...      ...
# 704         cases     2025          year        UR         canton      all
# 705         cases     2025          year        VD         canton      all
# 706         cases     2025          year        VS         canton      all
# 707         cases     2025          year        ZG         canton      all
# 708         cases     2025          year        ZH         canton      all
#
#      agegroup_type  sex  value        pop  incValue  valueYearCumSum  \
# 332  agegroup_food  all   11.0   636362.0      1.73              NaN
# 333  agegroup_food  all    0.0    15778.0      0.00              NaN
# 334  agegroup_food  all    0.0    53691.0      0.00              NaN
# 335  agegroup_food  all    9.0  1001281.0      0.90              NaN
# 336  agegroup_food  all    7.0   278656.0      2.51              NaN
# ..             ...  ...    ...        ...       ...              ...
# 704  agegroup_food  all    0.0    38275.0      0.00              NaN
# 705  agegroup_food  all   37.0   855106.0      4.33              NaN
# 706  agegroup_food  all   10.0   371288.0      2.69              NaN
# 707  agegroup_food  all    4.0   133739.0      2.99              NaN
# 708  agegroup_food  all   37.0  1620020.0      2.28              NaN
#
#      valueMean3y trend  prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 332          NaN   NaN   7.5         NaN            NaN                 NaN
# 333          NaN   NaN   0.0         NaN            NaN                 NaN
# 334          NaN   NaN   0.0         NaN            NaN                 NaN
# 335          NaN   NaN   6.1         NaN            NaN                 NaN
# 336          NaN   NaN   4.8         NaN            NaN                 NaN
# ..           ...   ...   ...         ...            ...                 ...
# 704          0.3   NaN   0.0         NaN            NaN                 NaN
# 705         34.0   NaN  15.9         NaN            NaN                 NaN
# 706          7.3   NaN   4.3         NaN            NaN                 NaN
# 707          4.7   NaN   1.7         NaN            NaN                 NaN
# 708         37.0   NaN  15.9         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 332          NaN          True
# 333          NaN          True
# 334          NaN          True
# 335          NaN          True
# 336          NaN          True
# ..           ...           ...
# 704          NaN          True
# 705          NaN          True
# 706          NaN          True
# 707          NaN          True
# 708          NaN          True
#
# [351 rows x 20 columns]

# %%
data_cantons_100 = data_cantons.copy()

# Wert pro 100000 einfügen
data_cantons_100["value_100000"] = data_cantons_100["value"] / data_cantons_100["pop"] * 100000

data_cantons_100["value_100000"] = data_cantons_100["value_100000"].round(1)

data_cantons_100
# Out:
#     valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 332         cases     2013          year        AG         canton      all
# 333         cases     2013          year        AI         canton      all
# 334         cases     2013          year        AR         canton      all
# 335         cases     2013          year        BE         canton      all
# 336         cases     2013          year        BL         canton      all
# ..            ...      ...           ...       ...            ...      ...
# 704         cases     2025          year        UR         canton      all
# 705         cases     2025          year        VD         canton      all
# 706         cases     2025          year        VS         canton      all
# 707         cases     2025          year        ZG         canton      all
# 708         cases     2025          year        ZH         canton      all
#
#      agegroup_type  sex  value        pop  ...  valueYearCumSum  valueMean3y  \
# 332  agegroup_food  all   11.0   636362.0  ...              NaN          NaN
# 333  agegroup_food  all    0.0    15778.0  ...              NaN          NaN
# 334  agegroup_food  all    0.0    53691.0  ...              NaN          NaN
# 335  agegroup_food  all    9.0  1001281.0  ...              NaN          NaN
# 336  agegroup_food  all    7.0   278656.0  ...              NaN          NaN
# ..             ...  ...    ...        ...  ...              ...          ...
# 704  agegroup_food  all    0.0    38275.0  ...              NaN          0.3
# 705  agegroup_food  all   37.0   855106.0  ...              NaN         34.0
# 706  agegroup_food  all   10.0   371288.0  ...              NaN          7.3
# 707  agegroup_food  all    4.0   133739.0  ...              NaN          4.7
# 708  agegroup_food  all   37.0  1620020.0  ...              NaN         37.0
#
#      trend  prct  deltaValue  deltaIncValue  incValuePrctChange  valueMean5y  \
# 332    NaN   7.5         NaN            NaN                 NaN          NaN
# 333    NaN   0.0         NaN            NaN                 NaN          NaN
# 334    NaN   0.0         NaN            NaN                 NaN          NaN
# 335    NaN   6.1         NaN            NaN                 NaN          NaN
# 336    NaN   4.8         NaN            NaN                 NaN          NaN
# ..     ...   ...         ...            ...                 ...          ...
# 704    NaN   0.0         NaN            NaN                 NaN          NaN
# 705    NaN  15.9         NaN            NaN                 NaN          NaN
# 706    NaN   4.3         NaN            NaN                 NaN          NaN
# 707    NaN   1.7         NaN            NaN                 NaN          NaN
# 708    NaN  15.9         NaN            NaN                 NaN          NaN
#
#      dataComplete  value_100000
# 332          True           1.7
# 333          True           0.0
# 334          True           0.0
# 335          True           0.9
# 336          True           2.5
# ..            ...           ...
# 704          True           0.0
# 705          True           4.3
# 706          True           2.7
# 707          True           3.0
# 708          True           2.3
#
# [351 rows x 21 columns]

# %%
# nur 2025
data_cantons_100_2025 = data_cantons_100[data_cantons_100["temporal"] == "2025"]

#Bar Chart
bar_georegion = alt.Chart(data_cantons_100_2025).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("value_100000", title="Mean Cases")
).properties(
    title="Shigellosis Georegion 2025 pro 100000"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value_100000:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)
