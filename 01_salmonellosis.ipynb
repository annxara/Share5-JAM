# %% [markdown]
# # Share 5 - BAG
# ## Salmonellosis
# * Übersicht: https://www.idd.bag.admin.ch/de/diseases/salmonellosis/overview
# * Daten: https://www.idd.bag.admin.ch/de/diseases/salmonellosis/data
#
# Werden monatlich geupdatet
#
# Obligatorische Meldung

# %%
# Importieren der Libraries

# Daten-Analyse
import pandas as pd

# Daten-Visualisierung
import altair as alt

# %% [markdown]
# ### Daten hereinladen

# %%
# Daten laden --> read_csv / read_excel
# Falls mehrere sheets --> sheet_name="sheet"


data = pd.read_csv("data/salmonellosis/data.csv")

data
# Out:
#         valueCategory  temporal temporal_type georegion georegion_type  \
# 0               cases  2013-M01         month      CHFL           CHFL
# 1               cases  2013-M02         month      CHFL           CHFL
# 2               cases  2013-M03         month      CHFL           CHFL
# 3               cases  2013-M04         month      CHFL           CHFL
# 4               cases  2013-M05         month      CHFL           CHFL
# ..                ...       ...           ...       ...            ...
# 821  cases_10y_cumsum      2024          year      CHFL           CHFL
# 822  cases_10y_cumsum      2024          year      CHFL           CHFL
# 823  cases_10y_cumsum      2025          year      CHFL           CHFL
# 824  cases_10y_cumsum      2025          year      CHFL           CHFL
# 825  cases_10y_cumsum      2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex type   value  ...  incValue  \
# 0        all  agegroup_food      all  all    87.0  ...      1.06
# 1        all  agegroup_food      all  all    76.0  ...      0.93
# 2        all  agegroup_food      all  all    63.0  ...      0.77
# 3        all  agegroup_food      all  all    92.0  ...      1.13
# 4        all  agegroup_food      all  all    88.0  ...      1.08
# ..       ...            ...      ...  ...     ...  ...       ...
# 821      all  agegroup_food     male  all  8385.0  ...       NaN
# 822      all  agegroup_food  unknown  all    17.0  ...       NaN
# 823      all  agegroup_food   female  all  8402.0  ...       NaN
# 824      all  agegroup_food     male  all  8899.0  ...       NaN
# 825      all  agegroup_food  unknown  all    19.0  ...       NaN
#
#      valueYearCumSum  valueMean3y     trend  prct  deltaValue  deltaIncValue  \
# 0               87.0          NaN       NaN   NaN         NaN            NaN
# 1              163.0          NaN       NaN   NaN         NaN            NaN
# 2              226.0          NaN       NaN   NaN         NaN            NaN
# 3              318.0          NaN  stagnant   NaN         NaN            NaN
# 4              406.0          NaN  stagnant   NaN         NaN            NaN
# ..               ...          ...       ...   ...         ...            ...
# 821              NaN          NaN       NaN  51.2         NaN            NaN
# 822              NaN          NaN       NaN   0.1         NaN            NaN
# 823              NaN          NaN       NaN  48.5         NaN            NaN
# 824              NaN          NaN       NaN  51.4         NaN            NaN
# 825              NaN          NaN       NaN   0.1         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 821                 NaN          NaN          True
# 822                 NaN          NaN          True
# 823                 NaN          NaN          True
# 824                 NaN          NaN          True
# 825                 NaN          NaN          True
#
# [826 rows x 21 columns]

# %% [markdown]
# ### Variablen

# %%
data.columns
# Out:
# Index(['valueCategory', 'temporal', 'temporal_type', 'georegion',
#        'georegion_type', 'agegroup', 'agegroup_type', 'sex', 'type', 'value',
#        'pop', 'incValue', 'valueYearCumSum', 'valueMean3y', 'trend', 'prct',
#        'deltaValue', 'deltaIncValue', 'incValuePrctChange', 'valueMean5y',
#        'dataComplete'],
#       dtype='object')

# %% [markdown]
# * valueCategory: Was gemessen wird --> Hier: Anzahl gemeldete Fälle
# * temporal: Welcher Zeitabschnitt --> Jahr und Monat
# * temporal_type: Typ der Zeit --> Monat
# * georegion: Kanton oder Land --> hier Anfang Land später Kanton
# * georegion_type: Typ der Georegion --> Land/Kantonal
# * agegroup: Alterskategorie
# * agegroup_type: Zuordnung zur Oberthema --> bei allen gleich
# * sex: Geschlecht
# * value: Wert basierend auf vorhergehende Kategorien
# * pop: Bevölkerung zum Zeitpunkt der Erhebung
# * incValue: neuaufgetrettene Fälle innerhalb der Gruppe und Zeit
# * valueYearCumSum: Gesamter Wert über das Jahr
# * valueMean3y: Durchschnittswert der letzten drei Jahre
# * trend: ist der Trend abnehmend(falling), gleich(stagnant) oder steigend(rising)
# * prct: prozentualer Anteil der Fälle in den Kategorien und Zeiteinheit
# * deltaValue: Unterschied des value zum vorherigen Wert
# * deltaIncValue: Unterschied des incValue zum vorherigen Wert
# * incValuePrctChange: Prozentualer Unterschied zum vorherigen Wert
# * valueMean5y: Durchschnittlicher Wert der letzten 5 Jahre
# * dataComplete: ist dieser Datenpunkt komplett

# %%
data.dtypes
# Out:
# valueCategory          object
# temporal               object
# temporal_type          object
# georegion              object
# georegion_type         object
# agegroup               object
# agegroup_type          object
# sex                    object
# type                   object
# value                 float64
# pop                   float64
# incValue              float64
# valueYearCumSum       float64
# valueMean3y           float64
# trend                  object
# prct                  float64
# deltaValue            float64
# deltaIncValue         float64
# incValuePrctChange    float64
# valueMean5y           float64
# dataComplete             bool
# dtype: object

# %% [markdown]
# ### Datensatz für Cases
#
# --> Die Durchschnittswerte sind als Einzelne Datenpunkte erhoben

# %%
data_def = data[data["valueCategory"] == "cases"]

data_def
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 785         cases      2025          year      CHFL           CHFL      all
# 786         cases      2025          year      CHFL           CHFL      all
# 787         cases      2025          year      CHFL           CHFL      all
# 788         cases      2025          year      CHFL           CHFL      all
# 789         cases      2025          year      CHFL           CHFL      all
#
#      agegroup_type  sex                               type  value  ...  \
# 0    agegroup_food  all                                all   87.0  ...
# 1    agegroup_food  all                                all   76.0  ...
# 2    agegroup_food  all                                all   63.0  ...
# 3    agegroup_food  all                                all   92.0  ...
# 4    agegroup_food  all                                all   88.0  ...
# ..             ...  ...                                ...    ...  ...
# 785  agegroup_food  all  monophasic_salmonella_typhimurium  111.0  ...
# 786  agegroup_food  all                             napoli   63.0  ...
# 787  agegroup_food  all                              other  759.0  ...
# 788  agegroup_food  all                            species  170.0  ...
# 789  agegroup_food  all                        typhimurium  360.0  ...
#
#      incValue  valueYearCumSum  valueMean3y     trend  prct  deltaValue  \
# 0        1.06             87.0          NaN       NaN   NaN         NaN
# 1        0.93            163.0          NaN       NaN   NaN         NaN
# 2        0.77            226.0          NaN       NaN   NaN         NaN
# 3        1.13            318.0          NaN  stagnant   NaN         NaN
# 4        1.08            406.0          NaN  stagnant   NaN         NaN
# ..        ...              ...          ...       ...   ...         ...
# 785      1.22              NaN        136.0       NaN   4.9         NaN
# 786      0.69              NaN         54.3       NaN   2.8         NaN
# 787      8.35              NaN        590.7       NaN  33.2         NaN
# 788      1.87              NaN        295.7       NaN   7.4         NaN
# 789      3.96              NaN        308.7       NaN  15.7         NaN
#
#      deltaIncValue  incValuePrctChange  valueMean5y  dataComplete
# 0              NaN                 NaN          NaN          True
# 1              NaN                 NaN          NaN          True
# 2              NaN                 NaN          NaN          True
# 3              NaN                 NaN          NaN          True
# 4              NaN                 NaN          NaN          True
# ..             ...                 ...          ...           ...
# 785            NaN                 NaN          NaN          True
# 786            NaN                 NaN          NaN          True
# 787            NaN                 NaN          NaN          True
# 788            NaN                 NaN          NaN          True
# 789            NaN                 NaN          NaN          True
#
# [622 rows x 21 columns]

# %% [markdown]
# ### Datensatz für Agegroup

# %%
data_med = data[data["valueCategory"] == "cases_10y_mean"]

data_med
# Out:
#       valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 790  cases_10y_mean     2022          year      CHFL           CHFL   0 - 16
# 791  cases_10y_mean     2022          year      CHFL           CHFL  17 - 24
# 792  cases_10y_mean     2022          year      CHFL           CHFL  25 - 44
# 793  cases_10y_mean     2022          year      CHFL           CHFL  45 - 64
# 794  cases_10y_mean     2022          year      CHFL           CHFL      65+
# 795  cases_10y_mean     2022          year      CHFL           CHFL  unknown
# 796  cases_10y_mean     2023          year      CHFL           CHFL   0 - 16
# 797  cases_10y_mean     2023          year      CHFL           CHFL  17 - 24
# 798  cases_10y_mean     2023          year      CHFL           CHFL  25 - 44
# 799  cases_10y_mean     2023          year      CHFL           CHFL  45 - 64
# 800  cases_10y_mean     2023          year      CHFL           CHFL      65+
# 801  cases_10y_mean     2023          year      CHFL           CHFL  unknown
# 802  cases_10y_mean     2024          year      CHFL           CHFL   0 - 16
# 803  cases_10y_mean     2024          year      CHFL           CHFL  17 - 24
# 804  cases_10y_mean     2024          year      CHFL           CHFL  25 - 44
# 805  cases_10y_mean     2024          year      CHFL           CHFL  45 - 64
# 806  cases_10y_mean     2024          year      CHFL           CHFL      65+
# 807  cases_10y_mean     2024          year      CHFL           CHFL  unknown
# 808  cases_10y_mean     2025          year      CHFL           CHFL   0 - 16
# 809  cases_10y_mean     2025          year      CHFL           CHFL  17 - 24
# 810  cases_10y_mean     2025          year      CHFL           CHFL  25 - 44
# 811  cases_10y_mean     2025          year      CHFL           CHFL  45 - 64
# 812  cases_10y_mean     2025          year      CHFL           CHFL      65+
# 813  cases_10y_mean     2025          year      CHFL           CHFL  unknown
#
#      agegroup_type  sex type  value  ...  incValue  valueYearCumSum  \
# 790  agegroup_food  all  all    NaN  ...     31.12              NaN
# 791  agegroup_food  all  all    NaN  ...     22.53              NaN
# 792  agegroup_food  all  all    NaN  ...     12.21              NaN
# 793  agegroup_food  all  all    NaN  ...     12.02              NaN
# 794  agegroup_food  all  all    NaN  ...     17.73              NaN
# 795  agegroup_food  all  all    NaN  ...       NaN              NaN
# 796  agegroup_food  all  all    NaN  ...     31.94              NaN
# 797  agegroup_food  all  all    NaN  ...     22.53              NaN
# 798  agegroup_food  all  all    NaN  ...     12.63              NaN
# 799  agegroup_food  all  all    NaN  ...     12.21              NaN
# 800  agegroup_food  all  all    NaN  ...     18.62              NaN
# 801  agegroup_food  all  all    NaN  ...       NaN              NaN
# 802  agegroup_food  all  all    NaN  ...     33.58              NaN
# 803  agegroup_food  all  all    NaN  ...     23.61              NaN
# 804  agegroup_food  all  all    NaN  ...     13.55              NaN
# 805  agegroup_food  all  all    NaN  ...     12.78              NaN
# 806  agegroup_food  all  all    NaN  ...     19.72              NaN
# 807  agegroup_food  all  all    NaN  ...       NaN              NaN
# 808  agegroup_food  all  all    NaN  ...     35.14              NaN
# 809  agegroup_food  all  all    NaN  ...     24.79              NaN
# 810  agegroup_food  all  all    NaN  ...     14.36              NaN
# 811  agegroup_food  all  all    NaN  ...     13.10              NaN
# 812  agegroup_food  all  all    NaN  ...     20.88              NaN
# 813  agegroup_food  all  all    NaN  ...       NaN              NaN
#
#      valueMean3y  trend prct  deltaValue  deltaIncValue  incValuePrctChange  \
# 790          NaN    NaN  NaN         NaN            NaN                 NaN
# 791          NaN    NaN  NaN         NaN            NaN                 NaN
# 792          NaN    NaN  NaN         NaN            NaN                 NaN
# 793          NaN    NaN  NaN         NaN            NaN                 NaN
# 794          NaN    NaN  NaN         NaN            NaN                 NaN
# 795          NaN    NaN  NaN         NaN            NaN                 NaN
# 796          NaN    NaN  NaN         NaN            NaN                 NaN
# 797          NaN    NaN  NaN         NaN            NaN                 NaN
# 798          NaN    NaN  NaN         NaN            NaN                 NaN
# 799          NaN    NaN  NaN         NaN            NaN                 NaN
# 800          NaN    NaN  NaN         NaN            NaN                 NaN
# 801          NaN    NaN  NaN         NaN            NaN                 NaN
# 802          NaN    NaN  NaN         NaN            NaN                 NaN
# 803          NaN    NaN  NaN         NaN            NaN                 NaN
# 804          NaN    NaN  NaN         NaN            NaN                 NaN
# 805          NaN    NaN  NaN         NaN            NaN                 NaN
# 806          NaN    NaN  NaN         NaN            NaN                 NaN
# 807          NaN    NaN  NaN         NaN            NaN                 NaN
# 808          NaN    NaN  NaN         NaN            NaN                 NaN
# 809          NaN    NaN  NaN         NaN            NaN                 NaN
# 810          NaN    NaN  NaN         NaN            NaN                 NaN
# 811          NaN    NaN  NaN         NaN            NaN                 NaN
# 812          NaN    NaN  NaN         NaN            NaN                 NaN
# 813          NaN    NaN  NaN         NaN            NaN                 NaN
#
#      valueMean5y  dataComplete
# 790          NaN          True
# 791          NaN          True
# 792          NaN          True
# 793          NaN          True
# 794          NaN          True
# 795          NaN          True
# 796          NaN          True
# 797          NaN          True
# 798          NaN          True
# 799          NaN          True
# 800          NaN          True
# 801          NaN          True
# 802          NaN          True
# 803          NaN          True
# 804          NaN          True
# 805          NaN          True
# 806          NaN          True
# 807          NaN          True
# 808          NaN          True
# 809          NaN          True
# 810          NaN          True
# 811          NaN          True
# 812          NaN          True
# 813          NaN          True
#
# [24 rows x 21 columns]

# %%
# Exportieren des Datensatzes für Fälle pro Altersklasse
# data_med.to_csv("./export/data_salmonellosis_fälle_altersklasse.csv", index=False)

# %% [markdown]
# ### Datensatz für Geschlecht

# %%
data_sex = data[data["valueCategory"] == "cases_10y_cumsum"]

data_sex
# Out:
#         valueCategory temporal temporal_type georegion georegion_type  \
# 814  cases_10y_cumsum     2022          year      CHFL           CHFL
# 815  cases_10y_cumsum     2022          year      CHFL           CHFL
# 816  cases_10y_cumsum     2022          year      CHFL           CHFL
# 817  cases_10y_cumsum     2023          year      CHFL           CHFL
# 818  cases_10y_cumsum     2023          year      CHFL           CHFL
# 819  cases_10y_cumsum     2023          year      CHFL           CHFL
# 820  cases_10y_cumsum     2024          year      CHFL           CHFL
# 821  cases_10y_cumsum     2024          year      CHFL           CHFL
# 822  cases_10y_cumsum     2024          year      CHFL           CHFL
# 823  cases_10y_cumsum     2025          year      CHFL           CHFL
# 824  cases_10y_cumsum     2025          year      CHFL           CHFL
# 825  cases_10y_cumsum     2025          year      CHFL           CHFL
#
#     agegroup  agegroup_type      sex type   value  ...  incValue  \
# 814      all  agegroup_food   female  all  7169.0  ...       NaN
# 815      all  agegroup_food     male  all  7628.0  ...       NaN
# 816      all  agegroup_food  unknown  all    15.0  ...       NaN
# 817      all  agegroup_food   female  all  7444.0  ...       NaN
# 818      all  agegroup_food     male  all  7906.0  ...       NaN
# 819      all  agegroup_food  unknown  all    14.0  ...       NaN
# 820      all  agegroup_food   female  all  7985.0  ...       NaN
# 821      all  agegroup_food     male  all  8385.0  ...       NaN
# 822      all  agegroup_food  unknown  all    17.0  ...       NaN
# 823      all  agegroup_food   female  all  8402.0  ...       NaN
# 824      all  agegroup_food     male  all  8899.0  ...       NaN
# 825      all  agegroup_food  unknown  all    19.0  ...       NaN
#
#      valueYearCumSum  valueMean3y  trend  prct  deltaValue  deltaIncValue  \
# 814              NaN          NaN    NaN  48.4         NaN            NaN
# 815              NaN          NaN    NaN  51.5         NaN            NaN
# 816              NaN          NaN    NaN   0.1         NaN            NaN
# 817              NaN          NaN    NaN  48.5         NaN            NaN
# 818              NaN          NaN    NaN  51.5         NaN            NaN
# 819              NaN          NaN    NaN   0.1         NaN            NaN
# 820              NaN          NaN    NaN  48.7         NaN            NaN
# 821              NaN          NaN    NaN  51.2         NaN            NaN
# 822              NaN          NaN    NaN   0.1         NaN            NaN
# 823              NaN          NaN    NaN  48.5         NaN            NaN
# 824              NaN          NaN    NaN  51.4         NaN            NaN
# 825              NaN          NaN    NaN   0.1         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 814                 NaN          NaN          True
# 815                 NaN          NaN          True
# 816                 NaN          NaN          True
# 817                 NaN          NaN          True
# 818                 NaN          NaN          True
# 819                 NaN          NaN          True
# 820                 NaN          NaN          True
# 821                 NaN          NaN          True
# 822                 NaN          NaN          True
# 823                 NaN          NaN          True
# 824                 NaN          NaN          True
# 825                 NaN          NaN          True
#
# [12 rows x 21 columns]

# %%
# Exportieren des Datensatzes für Fälle Geschlechterverteilung
# data_sex.to_csv("./export/data_salmonellosis_fälle_geschlecht.csv", index=False)

# %% [markdown]
# ### Visuelle Analyse

# %%
# Ohne Kantone --> ~
data_cantons = data_def[~data_def["georegion"].isin(["CH", "CHFL"])]

#Gruppieren nach georegion und Werte summieren
counts = (
    data_cantons.groupby("georegion")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_georegion = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("sum_value", title="Total Cases")
).properties(
    title="Salmonellosis Georegion 2013-2025"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * ZH am höchsten --> grösster Kanton
# * kleine Kantone --> weniger Fälle

# %%
# nur 2025
data_cantons_2025 = data_cantons[data_cantons["temporal"] == "2025"]

#Gruppieren nach georegion und Werte summieren
counts = (
    data_cantons_2025.groupby("georegion")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_georegion_2025 = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("sum_value", title="Total Cases")
).properties(
    title="Salmonellosis Georegion 2025"
)

# Textlabels
text = bar_georegion_2025.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_georegion_2025 = bar_georegion_2025 + text
bar_georegion_2025
# Out:
# alt.LayerChart(...)

# %%
#Gruppieren nach georegion und Werte summieren
counts = (
    data_def.groupby("temporal")
        .agg(sum_value=("value", "sum"))
        .reset_index()
)

#Bar Chart
bar_temporal = alt.Chart(counts).mark_bar(color="aqua").encode(
    x=alt.X("temporal", title="Temporal"),
    y=alt.Y("sum_value", title="Cases")
).properties(
    title="Salmonellosis Temporal"
)

# Textlabels
text = bar_temporal.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="sum_value:Q"
)

# Kombinieren
bar_temporal = bar_temporal + text
bar_temporal
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * Datensatz aufteilen in monatlich und Jährlich

# %%
data_1 = data_def.copy()

data_year = data_1[data_1["temporal_type"] == "year"]

data_year
# Out:
#     valueCategory temporal temporal_type georegion georegion_type agegroup  \
# 332         cases     2013          year        AG         canton      all
# 333         cases     2013          year        AI         canton      all
# 334         cases     2013          year        AR         canton      all
# 335         cases     2013          year        BE         canton      all
# 336         cases     2013          year        BL         canton      all
# ..            ...      ...           ...       ...            ...      ...
# 785         cases     2025          year      CHFL           CHFL      all
# 786         cases     2025          year      CHFL           CHFL      all
# 787         cases     2025          year      CHFL           CHFL      all
# 788         cases     2025          year      CHFL           CHFL      all
# 789         cases     2025          year      CHFL           CHFL      all
#
#      agegroup_type  sex                               type  value  ...  \
# 332  agegroup_food  all                                all   86.0  ...
# 333  agegroup_food  all                                all    0.0  ...
# 334  agegroup_food  all                                all   11.0  ...
# 335  agegroup_food  all                                all  141.0  ...
# 336  agegroup_food  all                                all   47.0  ...
# ..             ...  ...                                ...    ...  ...
# 785  agegroup_food  all  monophasic_salmonella_typhimurium  111.0  ...
# 786  agegroup_food  all                             napoli   63.0  ...
# 787  agegroup_food  all                              other  759.0  ...
# 788  agegroup_food  all                            species  170.0  ...
# 789  agegroup_food  all                        typhimurium  360.0  ...
#
#      incValue  valueYearCumSum  valueMean3y  trend  prct  deltaValue  \
# 332     13.51              NaN          NaN    NaN   6.8         NaN
# 333      0.00              NaN          NaN    NaN   0.0         NaN
# 334     20.49              NaN          NaN    NaN   0.9         NaN
# 335     14.08              NaN          NaN    NaN  11.1         NaN
# 336     16.87              NaN          NaN    NaN   3.7         NaN
# ..        ...              ...          ...    ...   ...         ...
# 785      1.22              NaN        136.0    NaN   4.9         NaN
# 786      0.69              NaN         54.3    NaN   2.8         NaN
# 787      8.35              NaN        590.7    NaN  33.2         NaN
# 788      1.87              NaN        295.7    NaN   7.4         NaN
# 789      3.96              NaN        308.7    NaN  15.7         NaN
#
#      deltaIncValue  incValuePrctChange  valueMean5y  dataComplete
# 332            NaN                 NaN          NaN          True
# 333            NaN                 NaN          NaN          True
# 334            NaN                 NaN          NaN          True
# 335            NaN                 NaN          NaN          True
# 336            NaN                 NaN          NaN          True
# ..             ...                 ...          ...           ...
# 785            NaN                 NaN          NaN          True
# 786            NaN                 NaN          NaN          True
# 787            NaN                 NaN          NaN          True
# 788            NaN                 NaN          NaN          True
# 789            NaN                 NaN          NaN          True
#
# [458 rows x 21 columns]

# %%
# Exportieren des Datensatzes für Fälle pro Kanton
# data_year.to_csv("./export/data_salmonellosis_fälle_georegion.csv", index=False)

# %%
# Ohne Kantone
data_year_CH = data_year[data_year["georegion"].isin(["CH"])]

bar_year = alt.Chart(data_year_CH).mark_bar().encode(
    x=alt.X("temporal", title="Temporal"),
    y=alt.Y("value", title="Cases")
).properties(
    title="Salmonellosis Year"
)

# Textlabels
text = bar_year.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_year = bar_year + text
bar_year
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * Steigende Fallzahlen in den letzten Jahren

# %%
data_2 = data_def.copy()

data_month = data_2[data_2["temporal_type"] == "month"]

data_month
# Out:
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 159         cases  2026-M04         month      CHFL           CHFL      all
# 160         cases  2026-M05         month      CHFL           CHFL      all
# 161         cases  2026-M06         month      CHFL           CHFL      all
# 162         cases  2026-M07         month      CHFL           CHFL      all
# 163         cases  2026-M08         month      CHFL           CHFL      all
#
#      agegroup_type  sex type  value  ...  incValue  valueYearCumSum  \
# 0    agegroup_food  all  all   87.0  ...      1.06             87.0
# 1    agegroup_food  all  all   76.0  ...      0.93            163.0
# 2    agegroup_food  all  all   63.0  ...      0.77            226.0
# 3    agegroup_food  all  all   92.0  ...      1.13            318.0
# 4    agegroup_food  all  all   88.0  ...      1.08            406.0
# ..             ...  ...  ...    ...  ...       ...              ...
# 159  agegroup_food  all  all  141.0  ...      1.55            472.0
# 160  agegroup_food  all  all  126.0  ...      1.39            598.0
# 161  agegroup_food  all  all  170.0  ...      1.87            768.0
# 162  agegroup_food  all  all  290.0  ...      3.19           1058.0
# 163  agegroup_food  all  all  555.0  ...      6.10           1613.0
#
#      valueMean3y     trend prct  deltaValue  deltaIncValue  \
# 0            NaN       NaN  NaN         NaN            NaN
# 1            NaN       NaN  NaN         NaN            NaN
# 2            NaN       NaN  NaN         NaN            NaN
# 3            NaN  stagnant  NaN         NaN            NaN
# 4            NaN  stagnant  NaN         NaN            NaN
# ..           ...       ...  ...         ...            ...
# 159          NaN  stagnant  NaN         NaN            NaN
# 160          NaN    rising  NaN         NaN            NaN
# 161          NaN    rising  NaN         NaN            NaN
# 162          NaN    rising  NaN         NaN            NaN
# 163          NaN    rising  NaN         NaN            NaN
#
#      incValuePrctChange  valueMean5y  dataComplete
# 0                   NaN          NaN          True
# 1                   NaN          NaN          True
# 2                   NaN          NaN          True
# 3                   NaN          NaN          True
# 4                   NaN          NaN          True
# ..                  ...          ...           ...
# 159                 NaN          NaN          True
# 160                 NaN          NaN          True
# 161                 NaN          NaN          True
# 162                 NaN          NaN          True
# 163                 NaN          NaN          True
#
# [164 rows x 21 columns]

# %%
# Exportieren des Datensatzes für Fälle pro Monat
# data_month.to_csv("./export/data_salmonellosis_fälle_monat.csv", index=False)

# %%
#Gruppieren nach Jahren und Werte summieren


bar_month = alt.Chart(data_month).mark_bar().encode(
    x=alt.X("temporal:N", title="Temporal"),
    y=alt.Y("value:Q", title="Cases"),
    color=alt.Color("trend:N")
).properties(
    title="Salmonellosis Month"
)

# Textlabels
text = bar_month.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_month = bar_month + text
bar_month
# Out:
# alt.LayerChart(...)

# %% [markdown]
# * im Sommer am Höchsten¨
# * im Winter tiefer
# * steigende Zahlen in den letzten Jahren

# %%
bar_age = alt.Chart(data_med).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases"),
    color=alt.Color("temporal")
).properties(
    title="Salmonellosis Altersgruppen 2022 - 2025"
)

bar_age
# Out:
# alt.Chart(...)

# %%
data_age_2025 = data_med[data_med["temporal"] == "2025"]

bar_age_2 = alt.Chart(data_age_2025).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("incValue", title="Cases")
).properties(
    title="Salmonellosis Altersgruppen 2025"
)

# Textlabels
text = bar_age_2.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="incValue:Q"
)

bar_age_2 = bar_age_2 + text

bar_age_2
# Out:
# alt.LayerChart(...)

# %%
bar_sex = alt.Chart(data_sex).mark_bar().encode(
    x=alt.X("sex", title="Sex"),
    y=alt.Y("value", title="Cases"),
    color=alt.Color("temporal")
).properties(
    title="Salmonellosis Geschlechterverteilung 2022 - 2025"
)

bar_sex
# Out:
# alt.Chart(...)

# %%
data_sex_2025 = data_sex[data_sex["temporal"] == "2025"]

bar_sex_2 = alt.Chart(data_sex_2025).mark_bar().encode(
    x=alt.X("sex", title="Geschlecht"),
    y=alt.Y("value", title="Cases")
).properties(
    title="Salmonellosis Geschlechterverteilung 2025"
)

# Textlabels
text = bar_sex_2.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="value:Q"
)

bar_sex_2 = bar_sex_2 + text
bar_sex_2
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Durchschnittsberechnungen & -visualisierungen

# %%
# Ohne Kantone --> ~
data_cantons = data_def[~data_def["georegion"].isin(["CH", "CHFL"])]

#Gruppieren nach georegion und Werte summieren
counts_mean = (
    data_cantons.groupby("georegion")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

#Bar Chart
bar_georegion = alt.Chart(counts_mean).mark_bar(color="aqua").encode(
    x=alt.X("georegion", title="Georegion"),
    y=alt.Y("mean_value", title="Mean Cases")
).properties(
    title="Salmonellosis Georegion 2013-2025 Mean"
)

# Textlabels
text = bar_georegion.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

# Kombinieren
bar_georegion = bar_georegion + text
bar_georegion
# Out:
# alt.LayerChart(...)

# %%
# Jahr und Monat trennen
data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)

data_month
# Out:
# /var/folders/wr/rgnzqf8x4w501ytwkhks5qfw0000gn/T/ipykernel_26628/2880901401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)
# /var/folders/wr/rgnzqf8x4w501ytwkhks5qfw0000gn/T/ipykernel_26628/2880901401.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_month[["year", "month"]] = data_def["temporal"].str.split("-", expand=True)
#     valueCategory  temporal temporal_type georegion georegion_type agegroup  \
# 0           cases  2013-M01         month      CHFL           CHFL      all
# 1           cases  2013-M02         month      CHFL           CHFL      all
# 2           cases  2013-M03         month      CHFL           CHFL      all
# 3           cases  2013-M04         month      CHFL           CHFL      all
# 4           cases  2013-M05         month      CHFL           CHFL      all
# ..            ...       ...           ...       ...            ...      ...
# 159         cases  2026-M04         month      CHFL           CHFL      all
# 160         cases  2026-M05         month      CHFL           CHFL      all
# 161         cases  2026-M06         month      CHFL           CHFL      all
# 162         cases  2026-M07         month      CHFL           CHFL      all
# 163         cases  2026-M08         month      CHFL           CHFL      all
#
#      agegroup_type  sex type  value  ...  valueMean3y     trend  prct  \
# 0    agegroup_food  all  all   87.0  ...          NaN       NaN   NaN
# 1    agegroup_food  all  all   76.0  ...          NaN       NaN   NaN
# 2    agegroup_food  all  all   63.0  ...          NaN       NaN   NaN
# 3    agegroup_food  all  all   92.0  ...          NaN  stagnant   NaN
# 4    agegroup_food  all  all   88.0  ...          NaN  stagnant   NaN
# ..             ...  ...  ...    ...  ...          ...       ...   ...
# 159  agegroup_food  all  all  141.0  ...          NaN  stagnant   NaN
# 160  agegroup_food  all  all  126.0  ...          NaN    rising   NaN
# 161  agegroup_food  all  all  170.0  ...          NaN    rising   NaN
# 162  agegroup_food  all  all  290.0  ...          NaN    rising   NaN
# 163  agegroup_food  all  all  555.0  ...          NaN    rising   NaN
#
#      deltaValue deltaIncValue  incValuePrctChange  valueMean5y  dataComplete  \
# 0           NaN           NaN                 NaN          NaN          True
# 1           NaN           NaN                 NaN          NaN          True
# 2           NaN           NaN                 NaN          NaN          True
# 3           NaN           NaN                 NaN          NaN          True
# 4           NaN           NaN                 NaN          NaN          True
# ..          ...           ...                 ...          ...           ...
# 159         NaN           NaN                 NaN          NaN          True
# 160         NaN           NaN                 NaN          NaN          True
# 161         NaN           NaN                 NaN          NaN          True
# 162         NaN           NaN                 NaN          NaN          True
# 163         NaN           NaN                 NaN          NaN          True
#
#      year  month
# 0    2013    M01
# 1    2013    M02
# 2    2013    M03
# 3    2013    M04
# 4    2013    M05
# ..    ...    ...
# 159  2026    M04
# 160  2026    M05
# 161  2026    M06
# 162  2026    M07
# 163  2026    M08
#
# [164 rows x 23 columns]

# %%
counts_mean = (
    data_month.groupby("month")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

bar_month = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("month:N", title="Month"),
    y=alt.Y("mean_value:Q", title="Cases")
).properties(
    title="Salmonellosis Month 2013-2026 Mean"
)

# Textlabels
text = bar_month.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_month = bar_month + text
bar_month
# Out:
# alt.LayerChart(...)

# %%
counts_mean = (
    data_med.groupby("agegroup")
        .agg(mean_value=("incValue", "mean")).round(0)
        .reset_index()
)

bar_age = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("agegroup", title="Agegroup"),
    y=alt.Y("mean_value", title="Cases")
).properties(
    title="Salmonellosis Altersgruppen 2022 - 2025 Mean IncValue"
)

# Textlabels
text = bar_age.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_age = bar_age + text
bar_age
# Out:
# alt.LayerChart(...)

# %%
counts_mean = (
    data_sex.groupby("sex")
        .agg(mean_value=("value", "mean")).round(0)
        .reset_index()
)

bar_sex = alt.Chart(counts_mean).mark_bar().encode(
    x=alt.X("sex", title="Sex"),
    y=alt.Y("mean_value", title="Cases")
).properties(
    title="Salmonellosis Geschlechterverteilung 2022 - 2025 Mean"
)

# Textlabels
text = bar_sex.mark_text(
    align="center",
    dy=-5,
    size=10
).encode(
    text="mean_value:Q"
)

bar_sex = bar_sex + text
bar_sex

bar_sex
# Out:
# alt.LayerChart(...)
